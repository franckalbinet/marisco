# %%
#| default_exp netcdf_to_csv

# %% [markdown]
# # NetCDF to Open Refine CSV (WIP)

# %% [markdown]
# ***

# %% [markdown]
# ## Packages import

# %%
#| export
from pathlib import Path # This module offers classes representing filesystem paths
import xarray as xr
from netCDF4 import Dataset
import pandas as pd
import xarray as xr
import numpy as np
from marisco.callbacks import (Callback, Transformer,
                               EncodeTimeCB, SanitizeLonLatCB)
import fastcore.all as fc # package that brings fastcore functionality, see https://fastcore.fast.ai/.
from cftime import num2pydate 
from marisco.configs import cfg, cdl_cfg, nuc_lut_path, unit_lut_path, detection_limit_lut_path, species_lut_path, bodyparts_lut_path, sediments_lut_path
from marisco.serializers import OpenRefineCsvEncoder
from functools import reduce,partial

# %% [markdown]
# Get the current working directory (cwd). .

# %%
#|eval: false
Path.cwd()
# Out:
# Path('/home/marisco/downloads/marisco/nbs/handlers')

# %%
# | export
fname_in = '../../_data/output/ospar_19950103_2021214.nc'
fname_out = '../../_data/output/ospar_test.csv'
ref_id=191 # OSPAR ref_id

# %% [markdown]
# ## Load NetCDF

# %%
# | export
def netcdf4_to_df(fname_in):  
    # Read nc file
    with Dataset(fname_in, "r", format='NETCDF4' ) as nc:
        # Read groups ('seawater', 'biota', 'sediment')
        groups= nc.groups.keys()
        # Read fill values 
        fill_value={}
        for group in groups:
            fill_value[group] = nc.groups[group].variables['sample'][:].fill_value
    
    # Create dictionary of dataframes
    dfs={}
    for group in groups:
        # Read dataset
        ds = xr.open_dataset(fname_in, group=group,  decode_times=False)
        # Create Pandas dataframe 
        dfs[group]=ds.to_dataframe()
        # If the index is not 'sample' then set the index to be 'sample'
        if dfs[group].index.name != 'sample':
            dfs[group].set_index("sample", inplace=True)
        # Drop the rows where 'sample' uses the fill_value.
        dfs[group]=dfs[group].drop(fill_value[group], axis=0, errors='ignore') 
    return(dfs)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
dfs
# Out:
# {'seawater':               lon        lat  smp_depth        time   h3  h3_unc  h3_dl  \
#  sample
#  100     -1.973889  57.998890        0.0  1281916800  NaN     NaN     -1
#  101     -2.486944  58.484444        0.0  1281916800  NaN     NaN     -1
#  102     -2.007222  58.994446        0.0  1281916800  NaN     NaN     -1
#  103     -1.973889  57.998890        0.0  1281916800  NaN     NaN     -1
#  104     -2.486944  58.484444        0.0  1281916800  NaN     NaN     -1
#  ...           ...        ...        ...         ...  ...     ...    ...
#  16394   13.265278  73.723053     1675.0  1538092800  NaN     NaN     -1
#  16399   13.265278  73.723053     1675.0  1538092800  5.1     NaN      3
#  18659   13.267500  73.723610     1680.0  1630713600  NaN     NaN     -1
#  18694   13.267500  73.723610     1680.0  1630713600  NaN     NaN     -1
#  9439   -12.666667  68.000000     1850.0   975283200  NaN     NaN     -1
#
#          h3_unit  tc99  tc99_unc  ...  ra226_dl  ra226_unit  ra228  ra228_unc  \
#  sample                           ...
#  100          -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  101          -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  102          -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  103          -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  104          -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  ...         ...   ...       ...  ...       ...         ...    ...        ...
#  16394        -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  16399         1   NaN       NaN  ...        -1          -1    NaN        NaN
#  18659        -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  18694        -1   NaN       NaN  ...        -1          -1    NaN        NaN
#  9439         -1   NaN       NaN  ...        -1          -1    NaN        NaN
#
#          ra228_dl  ra228_unit  pu239_240_tot  pu239_240_tot_unc  \
#  sample
#  100           -1          -1            NaN                NaN
#  101           -1          -1            NaN                NaN
#  102           -1          -1            NaN                NaN
#  103           -1          -1       0.000032       1.610000e-06
#  104           -1          -1       0.000031       1.565000e-06
#  ...          ...         ...            ...                ...
#  16394         -1          -1       0.000012       1.250000e-06
#  16399         -1          -1            NaN                NaN
#  18659         -1          -1            NaN                NaN
#  18694         -1          -1       0.000010       8.000000e-07
#  9439          -1          -1            NaN                NaN
#
#          pu239_240_tot_dl  pu239_240_tot_unit
#  sample
#  100                   -1                  -1
#  101                   -1                  -1
#  102                   -1                  -1
#  103                    2                   1
#  104                    2                   1
#  ...                  ...                 ...
#  16394                  2                   1
#  16399                 -1                  -1
#  18659                 -1                  -1
#  18694                  2                   1
#  9439                  -1                  -1
#
#  [10090 rows x 32 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  h3  \
#  sample
#  0      -4.901945  55.725277  1640908800         13      394         19 NaN
#  1      -3.240556  54.968887  1640908800         11       96         56 NaN
#  2      -3.791389  58.565834  1640908800         13      394         19 NaN
#  3      -3.647778  58.618610  1640908800         13      394         19 NaN
#  4      -2.398056  55.964722  1640908800         11       96         56 NaN
#  ...          ...        ...         ...        ...      ...        ...  ..
#  15305   7.566667  54.348331   789350400          4       99         52 NaN
#  15306   7.566667  54.348331   789350400          4       99         25 NaN
#  15307  -3.566111  54.455002   789264000         13      394         19 NaN
#  15308  -3.566111  54.455002   789264000         13      394         19 NaN
#  15309  -3.566111  54.455002   789264000         13      394         19 NaN
#
#          h3_dl  h3_unit   tc99  ...  pu238_dl  pu238_unit  am241  am241_unc  \
#  sample                         ...
#  0          -1       -1    NaN  ...        -1          -1    NaN        NaN
#  1          -1       -1   39.0  ...        -1          -1    NaN        NaN
#  2          -1       -1    NaN  ...        -1          -1    NaN        NaN
#  3          -1       -1    NaN  ...        -1          -1    NaN        NaN
#  4          -1       -1   16.0  ...        -1          -1    NaN        NaN
#  ...       ...      ...    ...  ...       ...         ...    ...        ...
#  15305      -1       -1    NaN  ...        -1          -1    NaN        NaN
#  15306      -1       -1    NaN  ...        -1          -1    NaN        NaN
#  15307      -1       -1    NaN  ...        -1          -1    NaN        NaN
#  15308      -1       -1    NaN  ...        -1          -1    NaN        NaN
#  15309      -1       -1  838.0  ...        -1          -1    NaN        NaN
#
#          am241_dl  am241_unit  pu239_240_tot  pu239_240_tot_unc  \
#  sample
#  0             -1          -1         0.3510              0.066
#  1             -1          -1            NaN                NaN
#  2             -1          -1         0.0938              0.018
#  3             -1          -1         1.5400              0.310
#  4             -1          -1            NaN                NaN
#  ...          ...         ...            ...                ...
#  15305         -1          -1            NaN                NaN
#  15306         -1          -1            NaN                NaN
#  15307         -1          -1            NaN                NaN
#  15308         -1          -1            NaN                NaN
#  15309         -1          -1            NaN                NaN
#
#          pu239_240_tot_dl  pu239_240_tot_unit
#  sample
#  0                      2                   5
#  1                     -1                  -1
#  2                      2                   5
#  3                      2                   5
#  4                     -1                  -1
#  ...                  ...                 ...
#  15305                 -1                  -1
#  15306                 -1                  -1
#  15307                 -1                  -1
#  15308                 -1                  -1
#  15309                 -1                  -1
#
#  [7997 rows x 45 columns]}

# %%
#|eval: false
dfs['seawater']
# Out:
#               lon        lat  smp_depth        time   h3  h3_unc  h3_dl  \
# sample
# 100     -1.973889  57.998890        0.0  1281916800  NaN     NaN     -1
# 101     -2.486944  58.484444        0.0  1281916800  NaN     NaN     -1
# 102     -2.007222  58.994446        0.0  1281916800  NaN     NaN     -1
# 103     -1.973889  57.998890        0.0  1281916800  NaN     NaN     -1
# 104     -2.486944  58.484444        0.0  1281916800  NaN     NaN     -1
# ...           ...        ...        ...         ...  ...     ...    ...
# 16394   13.265278  73.723053     1675.0  1538092800  NaN     NaN     -1
# 16399   13.265278  73.723053     1675.0  1538092800  5.1     NaN      3
# 18659   13.267500  73.723610     1680.0  1630713600  NaN     NaN     -1
# 18694   13.267500  73.723610     1680.0  1630713600  NaN     NaN     -1
# 9439   -12.666667  68.000000     1850.0   975283200  NaN     NaN     -1
#
#         h3_unit  tc99  tc99_unc  ...  ra226_dl  ra226_unit  ra228  ra228_unc  \
# sample                           ...
# 100          -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 101          -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 102          -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 103          -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 104          -1   NaN       NaN  ...        -1          -1    NaN        NaN
# ...         ...   ...       ...  ...       ...         ...    ...        ...
# 16394        -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 16399         1   NaN       NaN  ...        -1          -1    NaN        NaN
# 18659        -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 18694        -1   NaN       NaN  ...        -1          -1    NaN        NaN
# 9439         -1   NaN       NaN  ...        -1          -1    NaN        NaN
#
#         ra228_dl  ra228_unit  pu239_240_tot  pu239_240_tot_unc  \
# sample
# 100           -1          -1            NaN                NaN
# 101           -1          -1            NaN                NaN
# 102           -1          -1            NaN                NaN
# 103           -1          -1       0.000032       1.610000e-06
# 104           -1          -1       0.000031       1.565000e-06
# ...          ...         ...            ...                ...
# 16394         -1          -1       0.000012       1.250000e-06
# 16399         -1          -1            NaN                NaN
# 18659         -1          -1            NaN                NaN
# 18694         -1          -1       0.000010       8.000000e-07
# 9439          -1          -1            NaN                NaN
#
#         pu239_240_tot_dl  pu239_240_tot_unit
# sample
# 100                   -1                  -1
# 101                   -1                  -1
# 102                   -1                  -1
# 103                    2                   1
# 104                    2                   1
# ...                  ...                 ...
# 16394                  2                   1
# 16399                 -1                  -1
# 18659                 -1                  -1
# 18694                  2                   1
# 9439                  -1                  -1
#
# [10090 rows x 32 columns]

# %% [markdown]
# ## Transform data

# %% [markdown]
# ### Reshape: wide to long

# %%
#| export
class ReshapeWideToLong(Callback):
    "Convert data from wide to long with renamed columns."
    def __init__(self, columns='nuclide', values=['value']):
        fc.store_attr()
        # Retrieve all possible suffixes vars (e.g '_unc', '_dl', ...) from configs
        suff_cfg = [value['name'] for value in cdl_cfg()['vars']['suffixes'].values()]
        # Retrieve all possible nuclides
        nucs_cfg = pd.read_excel(nuc_lut_path())['nc_name'].to_list()
        nucs_cfg = [x for x in nucs_cfg if str(x) != 'nan'] # remove 'nan' from nuclide list
        # Retrieve all possible vars thats are not in vars suffixes
        self.vars_cfg=[x['name'] for var_key in cdl_cfg()['vars'].keys() for x in cdl_cfg()['vars'][var_key].values() if var_key != 'suffixes']
        # combine all possible nuclides with its suffixes.    
        value_name='Activity or MDA'
        derived_nucs_cols={value_name:nucs_cfg}     
        for suf in suff_cfg:
            derived_nucs_cols[suf]= [str(nuc)+str(suf) for nuc in nucs_cfg]
        self.derived_nucs_cols=derived_nucs_cols
           
    def melt(self, df):
        # Among all possible 'self.derived_nuc_cols' include the ones present in df.
        derived_nucs_cols={}
        for key,derived_nuc_cols in self.derived_nucs_cols.items():
            derived_nuc_cols = [col for col in derived_nuc_cols if col in df.columns]
            if derived_nuc_cols:
                derived_nucs_cols[key] = derived_nuc_cols
        
        # Among all possible 'self.vars_cfg' include the ones present in df.
        vars_cfg = [var for var in self.vars_cfg if var in df.columns]
        
        # Melt cols included in self.derived_nucs_cols        
        df=df.reset_index()  # Reset the index so 'sample' can be used with id_vars
        nuc_dfs={}
        for key,val in derived_nucs_cols.items():
            # Transpose nuclide_cols
            df_t=pd.melt(frame=df, id_vars=vars_cfg+['sample'], value_vars=val, var_name='nuclide', value_name=key)
            df_t['nuclide']=df_t['nuclide'].str.replace(key, '')
            # Keep rows where 'key' value is not nan
            df_t=df_t[df_t[key].notna()]
            nuc_dfs[key]=df_t
        
        # Merge dfs created from melt. 
        combine_on= vars_cfg + ['sample'] + ['nuclide']
        merged_df=reduce(lambda df1, df2: pd.merge(df1, df2,  how='outer', left_on= combine_on, right_on = combine_on), nuc_dfs.values())
        # Keep rows where either value_name (i.e.Activity or MDA ) or _unc are not 'nan'.
        merged_df = merged_df[merged_df[['Activity or MDA','_unc']].notna().any(axis=1)]
        return (merged_df)
    
    def __call__(self, tfm):
        for k in tfm.dfs.keys():
            tfm.dfs[k] = self.melt(tfm.dfs[k])

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong()])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit
#  3             0.000003  3.343000e-07    2      1
#  13            0.000014  1.370000e-06    2      1
#  14            0.001969  1.969200e-04    2      1
#  21            0.001646  1.645800e-04    2      1
#  31            0.000002  2.224000e-07    2      1
#  ...                ...           ...  ...    ...
#  70595         0.003642  2.414650e-04    2      1
#  70605         0.000007  7.249000e-07    2      1
#  70609         0.003575  2.377380e-04    2      1
#  70619         0.000004  5.670000e-07    2      1
#  70624         0.260000  7.280000e-03    2      1
#
#  [10090 rows x 10 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  _dl  _unit
#  1       11474   cs137           0.1800  0.014634    2      5
#  11       4714   cs137           0.2198  0.025633    2      5
#  21       6465   cs137           0.2090  0.008778    2      5
#  31       6466   cs137           0.1830  0.007503    2      5
#  41       6143   cs137           0.1696  0.018266    2      5
#  ...       ...     ...              ...       ...  ...    ...
#  79921     259   cs137           0.1200  0.013500    2      5
#  79931    1913   cs137           0.1200  0.020000    2      5
#  79941     140   cs137           0.0420  0.016500    2      5
#  79951    1878   cs137           0.1700  0.015000    2      5
#  79961    1865   cs137           0.1100  0.010000    2      5
#
#  [7997 rows x 12 columns]}

# %%
#|eval: false
tfm.dfs['biota']
# Out:
#              lon        lat        time  bio_group  species  body_part  \
# 1     -39.634445  66.784164  1017014400          4       99         52
# 11    -39.150002  62.116665  1375228800          4      426         52
# 21    -35.919998  64.289719  1287273600          4       99         52
# 31    -35.099998  64.720001  1287100800          4      381         52
# 41    -34.000000  64.000000  1306886400          4       99         52
# ...          ...        ...         ...        ...      ...        ...
# 79921  34.336113  72.420280  1629676800          4      404         34
# 79931  34.351665  72.426392  1535760000          4      404         52
# 79941  35.521946  78.758888  1632355200          4      402          3
# 79951  36.581112  73.510002  1536537600          4       99         52
# 79961  36.722500  75.334999  1536883200          4      404         52
#
#        sample nuclide  Activity or MDA      _unc  _dl  _unit
# 1       11474   cs137           0.1800  0.014634    2      5
# 11       4714   cs137           0.2198  0.025633    2      5
# 21       6465   cs137           0.2090  0.008778    2      5
# 31       6466   cs137           0.1830  0.007503    2      5
# 41       6143   cs137           0.1696  0.018266    2      5
# ...       ...     ...              ...       ...  ...    ...
# 79921     259   cs137           0.1200  0.013500    2      5
# 79931    1913   cs137           0.1200  0.020000    2      5
# 79941     140   cs137           0.0420  0.016500    2      5
# 79951    1878   cs137           0.1700  0.015000    2      5
# 79961    1865   cs137           0.1100  0.010000    2      5
#
# [7997 rows x 12 columns]

# %% [markdown]
# ***

# %% [markdown]
# ### Format: Time

# %%
#| export
class ParseTimeCB(Callback):
    def __init__(self, cfg): fc.store_attr()
    def __call__(self, tfm):
        for k in tfm.dfs.keys():
            tfm.dfs[k]['Sampling start date'] = tfm.dfs[k]['time'].apply(self.format_time)
    def format_time(self, x): 
        date = num2pydate(x, units=self.cfg['units']['time'])
        date=date.strftime('%d-%b-%Y')
        return date

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg())])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit Sampling start date
#  3             0.000003  3.343000e-07    2      1         15-Jun-2012
#  13            0.000014  1.370000e-06    2      1         15-Jun-2012
#  14            0.001969  1.969200e-04    2      1         15-Jun-2012
#  21            0.001646  1.645800e-04    2      1         14-Jun-2013
#  31            0.000002  2.224000e-07    2      1         15-Jun-2012
#  ...                ...           ...  ...    ...                 ...
#  70595         0.003642  2.414650e-04    2      1         05-Jul-1995
#  70605         0.000007  7.249000e-07    2      1         05-Jul-1995
#  70609         0.003575  2.377380e-04    2      1         06-Jul-1995
#  70619         0.000004  5.670000e-07    2      1         06-Jul-1995
#  70624         0.260000  7.280000e-03    2      1         06-Jul-1995
#
#  [10090 rows x 11 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  _dl  _unit  \
#  1       11474   cs137           0.1800  0.014634    2      5
#  11       4714   cs137           0.2198  0.025633    2      5
#  21       6465   cs137           0.2090  0.008778    2      5
#  31       6466   cs137           0.1830  0.007503    2      5
#  41       6143   cs137           0.1696  0.018266    2      5
#  ...       ...     ...              ...       ...  ...    ...
#  79921     259   cs137           0.1200  0.013500    2      5
#  79931    1913   cs137           0.1200  0.020000    2      5
#  79941     140   cs137           0.0420  0.016500    2      5
#  79951    1878   cs137           0.1700  0.015000    2      5
#  79961    1865   cs137           0.1100  0.010000    2      5
#
#        Sampling start date
#  1             25-Mar-2002
#  11            31-Jul-2013
#  21            17-Oct-2010
#  31            15-Oct-2010
#  41            01-Jun-2011
#  ...                   ...
#  79921         23-Aug-2021
#  79931         01-Sep-2018
#  79941         23-Sep-2021
#  79951         10-Sep-2018
#  79961         14-Sep-2018
#
#  [7997 rows x 13 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup: Sample Type

# %%
#| export
class LookupSampleType(Callback):
    def __init__(self): fc.store_attr()
    def __call__(self, tfm):
        for k in tfm.dfs.keys():
            tfm.dfs[k]['Sample type'] = k.upper()

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType()])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit Sampling start date  \
#  3             0.000003  3.343000e-07    2      1         15-Jun-2012
#  13            0.000014  1.370000e-06    2      1         15-Jun-2012
#  14            0.001969  1.969200e-04    2      1         15-Jun-2012
#  21            0.001646  1.645800e-04    2      1         14-Jun-2013
#  31            0.000002  2.224000e-07    2      1         15-Jun-2012
#  ...                ...           ...  ...    ...                 ...
#  70595         0.003642  2.414650e-04    2      1         05-Jul-1995
#  70605         0.000007  7.249000e-07    2      1         05-Jul-1995
#  70609         0.003575  2.377380e-04    2      1         06-Jul-1995
#  70619         0.000004  5.670000e-07    2      1         06-Jul-1995
#  70624         0.260000  7.280000e-03    2      1         06-Jul-1995
#
#        Sample type
#  3        SEAWATER
#  13       SEAWATER
#  14       SEAWATER
#  21       SEAWATER
#  31       SEAWATER
#  ...           ...
#  70595    SEAWATER
#  70605    SEAWATER
#  70609    SEAWATER
#  70619    SEAWATER
#  70624    SEAWATER
#
#  [10090 rows x 12 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  _dl  _unit  \
#  1       11474   cs137           0.1800  0.014634    2      5
#  11       4714   cs137           0.2198  0.025633    2      5
#  21       6465   cs137           0.2090  0.008778    2      5
#  31       6466   cs137           0.1830  0.007503    2      5
#  41       6143   cs137           0.1696  0.018266    2      5
#  ...       ...     ...              ...       ...  ...    ...
#  79921     259   cs137           0.1200  0.013500    2      5
#  79931    1913   cs137           0.1200  0.020000    2      5
#  79941     140   cs137           0.0420  0.016500    2      5
#  79951    1878   cs137           0.1700  0.015000    2      5
#  79961    1865   cs137           0.1100  0.010000    2      5
#
#        Sampling start date Sample type
#  1             25-Mar-2002       BIOTA
#  11            31-Jul-2013       BIOTA
#  21            17-Oct-2010       BIOTA
#  31            15-Oct-2010       BIOTA
#  41            01-Jun-2011       BIOTA
#  ...                   ...         ...
#  79921         23-Aug-2021       BIOTA
#  79931         01-Sep-2018       BIOTA
#  79941         23-Sep-2021       BIOTA
#  79951         10-Sep-2018       BIOTA
#  79961         14-Sep-2018       BIOTA
#
#  [7997 rows x 14 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Nuclide

# %%
#| export
def get_nucnames_lut():
    df = pd.read_excel(nuc_lut_path(), usecols=['nc_name','nusymbol'])
    return df.set_index('nc_name').to_dict()['nusymbol']

# %%
# | export
class LookupNuclideIdCB(Callback):
    "Lookup MARIS nuclide_id."
    def __init__(self,
                 fn_lut=get_nucnames_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            tfm.dfs[k]['Nuclide'] = tfm.dfs[k]['nuclide'].replace(lut)
            tfm.dfs[k]['Nuclide']=tfm.dfs[k]['Nuclide'].str.strip()
            tfm.dfs[k]['Nuclide']=tfm.dfs[k]['Nuclide'].str.replace(',','_')

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit Sampling start date  \
#  3             0.000003  3.343000e-07    2      1         15-Jun-2012
#  13            0.000014  1.370000e-06    2      1         15-Jun-2012
#  14            0.001969  1.969200e-04    2      1         15-Jun-2012
#  21            0.001646  1.645800e-04    2      1         14-Jun-2013
#  31            0.000002  2.224000e-07    2      1         15-Jun-2012
#  ...                ...           ...  ...    ...                 ...
#  70595         0.003642  2.414650e-04    2      1         05-Jul-1995
#  70605         0.000007  7.249000e-07    2      1         05-Jul-1995
#  70609         0.003575  2.377380e-04    2      1         06-Jul-1995
#  70619         0.000004  5.670000e-07    2      1         06-Jul-1995
#  70624         0.260000  7.280000e-03    2      1         06-Jul-1995
#
#        Sample type    Nuclide
#  3        SEAWATER  239_240Pu
#  13       SEAWATER       99Tc
#  14       SEAWATER      137Cs
#  21       SEAWATER      137Cs
#  31       SEAWATER  239_240Pu
#  ...           ...        ...
#  70595    SEAWATER      137Cs
#  70605    SEAWATER  239_240Pu
#  70609    SEAWATER      137Cs
#  70619    SEAWATER  239_240Pu
#  70624    SEAWATER         3H
#
#  [10090 rows x 13 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  _dl  _unit  \
#  1       11474   cs137           0.1800  0.014634    2      5
#  11       4714   cs137           0.2198  0.025633    2      5
#  21       6465   cs137           0.2090  0.008778    2      5
#  31       6466   cs137           0.1830  0.007503    2      5
#  41       6143   cs137           0.1696  0.018266    2      5
#  ...       ...     ...              ...       ...  ...    ...
#  79921     259   cs137           0.1200  0.013500    2      5
#  79931    1913   cs137           0.1200  0.020000    2      5
#  79941     140   cs137           0.0420  0.016500    2      5
#  79951    1878   cs137           0.1700  0.015000    2      5
#  79961    1865   cs137           0.1100  0.010000    2      5
#
#        Sampling start date Sample type Nuclide
#  1             25-Mar-2002       BIOTA   137Cs
#  11            31-Jul-2013       BIOTA   137Cs
#  21            17-Oct-2010       BIOTA   137Cs
#  31            15-Oct-2010       BIOTA   137Cs
#  41            01-Jun-2011       BIOTA   137Cs
#  ...                   ...         ...     ...
#  79921         23-Aug-2021       BIOTA   137Cs
#  79931         01-Sep-2018       BIOTA   137Cs
#  79941         23-Sep-2021       BIOTA   137Cs
#  79951         10-Sep-2018       BIOTA   137Cs
#  79961         14-Sep-2018       BIOTA   137Cs
#
#  [7997 rows x 15 columns]}

# %%
#|eval: false
tfm.dfs['biota']['Nuclide'].unique()
# Out:
# array(['137Cs', '210Po', '99Tc', '239_240Pu', '238Pu', '241Am', '210Pb',
#        '226Ra', '228Ra', '3H'], dtype=object)

# %% [markdown]
# ***

# %% [markdown]
# ### Format : Longitude and Latitude

# %% [markdown]
# Convert from Longitude and Latitude DDD.DDDDD° to degrees, minutes, seconds and direction.

# %%
# | export
def deg_to_dms(deg, coordinate='lat'):
    """Convert from decimal degrees to degrees, minutes, seconds."""
    m, s = divmod(abs(deg)*3600, 60)
    d, m = divmod(m, 60)
    
    if deg < 0:
        if coordinate == 'lat':
            cord = 'S'
        elif coordinate == 'lon':
            cord = 'W'
    else:
        if coordinate == 'lat':
            cord = 'N' 
        elif coordinate == 'lon':
            cord = 'E'                       
        
    d, m = int(d), int(m)
    
    return pd.Series([d, m, s, cord])

# %%
# | export
class ConvertLonLatCB(Callback):
    "Convert from Longitude and Latitude DDD.DDDDD° to degrees, minutes, seconds and direction."
    def __init__(self, fn_convert=deg_to_dms):
        fc.store_attr()

    def __call__(self, tfm):
        for grp in tfm.dfs.keys():
            tfm.dfs[grp][['Latitude degrees','Latitude minutes','Latitude seconds','Latitude direction']] = tfm.dfs[grp]['lat'].apply(self.fn_convert, coordinate='lat')
            tfm.dfs[grp][['Longitude degrees','Longitude minutes','Longitude seconds','Longitude direction']] = tfm.dfs[grp]['lon'].apply(self.fn_convert, coordinate='lon')

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ... Sample type    Nuclide  \
#  3             0.000003  3.343000e-07    2      1  ...    SEAWATER  239_240Pu
#  13            0.000014  1.370000e-06    2      1  ...    SEAWATER       99Tc
#  14            0.001969  1.969200e-04    2      1  ...    SEAWATER      137Cs
#  21            0.001646  1.645800e-04    2      1  ...    SEAWATER      137Cs
#  31            0.000002  2.224000e-07    2      1  ...    SEAWATER  239_240Pu
#  ...                ...           ...  ...    ...  ...         ...        ...
#  70595         0.003642  2.414650e-04    2      1  ...    SEAWATER      137Cs
#  70605         0.000007  7.249000e-07    2      1  ...    SEAWATER  239_240Pu
#  70609         0.003575  2.377380e-04    2      1  ...    SEAWATER      137Cs
#  70619         0.000004  5.670000e-07    2      1  ...    SEAWATER  239_240Pu
#  70624         0.260000  7.280000e-03    2      1  ...    SEAWATER         3H
#
#        Latitude degrees  Latitude minutes  Latitude seconds  \
#  3                   68                48         59.996338
#  13                  68                48         59.996338
#  14                  68                48         59.996338
#  21                  68                 6          1.807251
#  31                  72                 6         52.207031
#  ...                ...               ...               ...
#  70595               72                30          0.000000
#  70605               72                30          0.000000
#  70609               74                 0          0.000000
#  70619               74                 0          0.000000
#  70624               74                 0          0.000000
#
#         Latitude direction Longitude degrees  Longitude minutes  \
#  3                       N                58                 13
#  13                      N                58                 13
#  14                      N                58                 13
#  21                      N                57                 47
#  31                      N                57                 34
#  ...                   ...               ...                ...
#  70595                   N                40                  0
#  70605                   N                40                  0
#  70609                   N                40                  0
#  70619                   N                40                  0
#  70624                   N                40                  0
#
#         Longitude seconds  Longitude direction
#  3              53.999634                    W
#  13             53.999634                    W
#  14             53.999634                    W
#  21             36.596375                    W
#  31             55.202637                    W
#  ...                  ...                  ...
#  70595           0.000000                    E
#  70605           0.000000                    E
#  70609           0.000000                    E
#  70619           0.000000                    E
#  70624           0.000000                    E
#
#  [10090 rows x 21 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Sample type  Nuclide  \
#  1       11474   cs137           0.1800  0.014634  ...        BIOTA    137Cs
#  11       4714   cs137           0.2198  0.025633  ...        BIOTA    137Cs
#  21       6465   cs137           0.2090  0.008778  ...        BIOTA    137Cs
#  31       6466   cs137           0.1830  0.007503  ...        BIOTA    137Cs
#  41       6143   cs137           0.1696  0.018266  ...        BIOTA    137Cs
#  ...       ...     ...              ...       ...  ...          ...      ...
#  79921     259   cs137           0.1200  0.013500  ...        BIOTA    137Cs
#  79931    1913   cs137           0.1200  0.020000  ...        BIOTA    137Cs
#  79941     140   cs137           0.0420  0.016500  ...        BIOTA    137Cs
#  79951    1878   cs137           0.1700  0.015000  ...        BIOTA    137Cs
#  79961    1865   cs137           0.1100  0.010000  ...        BIOTA    137Cs
#
#        Latitude degrees Latitude minutes Latitude seconds  Latitude direction  \
#  1                   66               47         2.991943                   N
#  11                  62                6        59.993591                   N
#  21                  64               17        22.987061                   N
#  31                  64               43        12.004395                   N
#  41                  64                0         0.000000                   N
#  ...                ...              ...              ...                 ...
#  79921               72               25        13.009644                   N
#  79931               72               25        35.009766                   N
#  79941               78               45        31.997681                   N
#  79951               73               30        36.007690                   N
#  79961               75               20         5.996704                   N
#
#         Longitude degrees  Longitude minutes Longitude seconds  \
#  1                     39                 38          4.002686
#  11                    39                  9          0.005493
#  21                    35                 55         11.993408
#  31                    35                  5         59.994507
#  41                    34                  0          0.000000
#  ...                  ...                ...               ...
#  79921                 34                 20         10.006714
#  79931                 34                 21          5.995789
#  79941                 35                 31         19.005432
#  79951                 36                 34         52.002869
#  79961                 36                 43         20.999451
#
#         Longitude direction
#  1                        W
#  11                       W
#  21                       W
#  31                       W
#  41                       W
#  ...                    ...
#  79921                    E
#  79931                    E
#  79941                    E
#  79951                    E
#  79961                    E
#
#  [7997 rows x 23 columns]}

# %%
#|eval: false
tfm.dfs['seawater'].columns
# Out:
# Index(['lon', 'lat', 'smp_depth', 'time', 'sample', 'nuclide',
#        'Activity or MDA', '_unc', '_dl', '_unit', 'Sampling start date',
#        'Sample type', 'Nuclide', 'Latitude degrees', 'Latitude minutes',
#        'Latitude seconds', 'Latitude direction', 'Longitude degrees',
#        'Longitude minutes', 'Longitude seconds', 'Longitude direction'],
#       dtype='object')

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Units

# %%
#| export
def get_unitnames_lut():
    df = pd.read_excel(unit_lut_path(), usecols=['unit_id','unit'])
    return df.set_index('unit_id').to_dict()['unit']

# %%
# | export
class LookupUnitIdCB(Callback):
    "Lookup MARIS unit by unit_id."
    def __init__(self,
                 fn_lut=get_unitnames_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            tfm.dfs[k]['Unit'] = tfm.dfs[k]['_unit'].replace(lut)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ...    Nuclide  \
#  3             0.000003  3.343000e-07    2      1  ...  239_240Pu
#  13            0.000014  1.370000e-06    2      1  ...       99Tc
#  14            0.001969  1.969200e-04    2      1  ...      137Cs
#  21            0.001646  1.645800e-04    2      1  ...      137Cs
#  31            0.000002  2.224000e-07    2      1  ...  239_240Pu
#  ...                ...           ...  ...    ...  ...        ...
#  70595         0.003642  2.414650e-04    2      1  ...      137Cs
#  70605         0.000007  7.249000e-07    2      1  ...  239_240Pu
#  70609         0.003575  2.377380e-04    2      1  ...      137Cs
#  70619         0.000004  5.670000e-07    2      1  ...  239_240Pu
#  70624         0.260000  7.280000e-03    2      1  ...         3H
#
#        Latitude degrees Latitude minutes  Latitude seconds  Latitude direction  \
#  3                   68               48         59.996338                   N
#  13                  68               48         59.996338                   N
#  14                  68               48         59.996338                   N
#  21                  68                6          1.807251                   N
#  31                  72                6         52.207031                   N
#  ...                ...              ...               ...                 ...
#  70595               72               30          0.000000                   N
#  70605               72               30          0.000000                   N
#  70609               74                0          0.000000                   N
#  70619               74                0          0.000000                   N
#  70624               74                0          0.000000                   N
#
#         Longitude degrees Longitude minutes  Longitude seconds  \
#  3                     58                13          53.999634
#  13                    58                13          53.999634
#  14                    58                13          53.999634
#  21                    57                47          36.596375
#  31                    57                34          55.202637
#  ...                  ...               ...                ...
#  70595                 40                 0           0.000000
#  70605                 40                 0           0.000000
#  70609                 40                 0           0.000000
#  70619                 40                 0           0.000000
#  70624                 40                 0           0.000000
#
#         Longitude direction   Unit
#  3                        W  Bq/m3
#  13                       W  Bq/m3
#  14                       W  Bq/m3
#  21                       W  Bq/m3
#  31                       W  Bq/m3
#  ...                    ...    ...
#  70595                    E  Bq/m3
#  70605                    E  Bq/m3
#  70609                    E  Bq/m3
#  70619                    E  Bq/m3
#  70624                    E  Bq/m3
#
#  [10090 rows x 22 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Nuclide  \
#  1       11474   cs137           0.1800  0.014634  ...    137Cs
#  11       4714   cs137           0.2198  0.025633  ...    137Cs
#  21       6465   cs137           0.2090  0.008778  ...    137Cs
#  31       6466   cs137           0.1830  0.007503  ...    137Cs
#  41       6143   cs137           0.1696  0.018266  ...    137Cs
#  ...       ...     ...              ...       ...  ...      ...
#  79921     259   cs137           0.1200  0.013500  ...    137Cs
#  79931    1913   cs137           0.1200  0.020000  ...    137Cs
#  79941     140   cs137           0.0420  0.016500  ...    137Cs
#  79951    1878   cs137           0.1700  0.015000  ...    137Cs
#  79961    1865   cs137           0.1100  0.010000  ...    137Cs
#
#         Latitude degrees Latitude minutes Latitude seconds Latitude direction  \
#  1                    66               47         2.991943                  N
#  11                   62                6        59.993591                  N
#  21                   64               17        22.987061                  N
#  31                   64               43        12.004395                  N
#  41                   64                0         0.000000                  N
#  ...                 ...              ...              ...                ...
#  79921                72               25        13.009644                  N
#  79931                72               25        35.009766                  N
#  79941                78               45        31.997681                  N
#  79951                73               30        36.007690                  N
#  79961                75               20         5.996704                  N
#
#         Longitude degrees  Longitude minutes  Longitude seconds  \
#  1                     39                 38           4.002686
#  11                    39                  9           0.005493
#  21                    35                 55          11.993408
#  31                    35                  5          59.994507
#  41                    34                  0           0.000000
#  ...                  ...                ...                ...
#  79921                 34                 20          10.006714
#  79931                 34                 21           5.995789
#  79941                 35                 31          19.005432
#  79951                 36                 34          52.002869
#  79961                 36                 43          20.999451
#
#        Longitude direction    Unit
#  1                       W  Bq/kgw
#  11                      W  Bq/kgw
#  21                      W  Bq/kgw
#  31                      W  Bq/kgw
#  41                      W  Bq/kgw
#  ...                   ...     ...
#  79921                   E  Bq/kgw
#  79931                   E  Bq/kgw
#  79941                   E  Bq/kgw
#  79951                   E  Bq/kgw
#  79961                   E  Bq/kgw
#
#  [7997 rows x 24 columns]}

# %%
#|eval: false
tfm.dfs['seawater'].columns
# Out:
# Index(['lon', 'lat', 'smp_depth', 'time', 'sample', 'nuclide',
#        'Activity or MDA', '_unc', '_dl', '_unit', 'Sampling start date',
#        'Sample type', 'Nuclide', 'Latitude degrees', 'Latitude minutes',
#        'Latitude seconds', 'Latitude direction', 'Longitude degrees',
#        'Longitude minutes', 'Longitude seconds', 'Longitude direction',
#        'Unit'],
#       dtype='object')

# %%
#|eval: false
tfm.dfs['seawater']['_dl']
# Out:
# 3        2
# 13       2
# 14       2
# 21       2
# 31       2
#         ..
# 70595    2
# 70605    2
# 70609    2
# 70619    2
# 70624    2
# Name: _dl, Length: 10090, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Value type (_dl)

# %%
#| export
def get_detectionlimitnames_lut():
    df = pd.read_excel(detection_limit_lut_path(), usecols=['id','name'])
    return df.set_index('id').to_dict()['name']

# %%
# | export
class LookupValueTypeIdCB(Callback):
    "Lookup MARIS Value Type."
    def __init__(self,
                 fn_lut=get_detectionlimitnames_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            tfm.dfs[k]['Value type'] = tfm.dfs[k]['_dl'].replace(lut)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ... Latitude degrees  \
#  3             0.000003  3.343000e-07    2      1  ...               68
#  13            0.000014  1.370000e-06    2      1  ...               68
#  14            0.001969  1.969200e-04    2      1  ...               68
#  21            0.001646  1.645800e-04    2      1  ...               68
#  31            0.000002  2.224000e-07    2      1  ...               72
#  ...                ...           ...  ...    ...  ...              ...
#  70595         0.003642  2.414650e-04    2      1  ...               72
#  70605         0.000007  7.249000e-07    2      1  ...               72
#  70609         0.003575  2.377380e-04    2      1  ...               74
#  70619         0.000004  5.670000e-07    2      1  ...               74
#  70624         0.260000  7.280000e-03    2      1  ...               74
#
#        Latitude minutes Latitude seconds  Latitude direction  \
#  3                   48        59.996338                   N
#  13                  48        59.996338                   N
#  14                  48        59.996338                   N
#  21                   6         1.807251                   N
#  31                   6        52.207031                   N
#  ...                ...              ...                 ...
#  70595               30         0.000000                   N
#  70605               30         0.000000                   N
#  70609                0         0.000000                   N
#  70619                0         0.000000                   N
#  70624                0         0.000000                   N
#
#         Longitude degrees  Longitude minutes Longitude seconds  \
#  3                     58                 13         53.999634
#  13                    58                 13         53.999634
#  14                    58                 13         53.999634
#  21                    57                 47         36.596375
#  31                    57                 34         55.202637
#  ...                  ...                ...               ...
#  70595                 40                  0          0.000000
#  70605                 40                  0          0.000000
#  70609                 40                  0          0.000000
#  70619                 40                  0          0.000000
#  70624                 40                  0          0.000000
#
#         Longitude direction   Unit  Value type
#  3                        W  Bq/m3           <
#  13                       W  Bq/m3           <
#  14                       W  Bq/m3           <
#  21                       W  Bq/m3           <
#  31                       W  Bq/m3           <
#  ...                    ...    ...         ...
#  70595                    E  Bq/m3           <
#  70605                    E  Bq/m3           <
#  70609                    E  Bq/m3           <
#  70619                    E  Bq/m3           <
#  70624                    E  Bq/m3           <
#
#  [10090 rows x 23 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Latitude degrees  \
#  1       11474   cs137           0.1800  0.014634  ...                66
#  11       4714   cs137           0.2198  0.025633  ...                62
#  21       6465   cs137           0.2090  0.008778  ...                64
#  31       6466   cs137           0.1830  0.007503  ...                64
#  41       6143   cs137           0.1696  0.018266  ...                64
#  ...       ...     ...              ...       ...  ...               ...
#  79921     259   cs137           0.1200  0.013500  ...                72
#  79931    1913   cs137           0.1200  0.020000  ...                72
#  79941     140   cs137           0.0420  0.016500  ...                78
#  79951    1878   cs137           0.1700  0.015000  ...                73
#  79961    1865   cs137           0.1100  0.010000  ...                75
#
#         Latitude minutes Latitude seconds Latitude direction Longitude degrees  \
#  1                    47         2.991943                  N                39
#  11                    6        59.993591                  N                39
#  21                   17        22.987061                  N                35
#  31                   43        12.004395                  N                35
#  41                    0         0.000000                  N                34
#  ...                 ...              ...                ...               ...
#  79921                25        13.009644                  N                34
#  79931                25        35.009766                  N                34
#  79941                45        31.997681                  N                35
#  79951                30        36.007690                  N                36
#  79961                20         5.996704                  N                36
#
#         Longitude minutes  Longitude seconds  Longitude direction    Unit  \
#  1                     38           4.002686                    W  Bq/kgw
#  11                     9           0.005493                    W  Bq/kgw
#  21                    55          11.993408                    W  Bq/kgw
#  31                     5          59.994507                    W  Bq/kgw
#  41                     0           0.000000                    W  Bq/kgw
#  ...                  ...                ...                  ...     ...
#  79921                 20          10.006714                    E  Bq/kgw
#  79931                 21           5.995789                    E  Bq/kgw
#  79941                 31          19.005432                    E  Bq/kgw
#  79951                 34          52.002869                    E  Bq/kgw
#  79961                 43          20.999451                    E  Bq/kgw
#
#         Value type
#  1               <
#  11              <
#  21              <
#  31              <
#  41              <
#  ...           ...
#  79921           <
#  79931           <
#  79941           <
#  79951           <
#  79961           <
#
#  [7997 rows x 25 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Biogroup

# %% [markdown]
# Biogroup not used in OPEN REfINE csv format. Confirm this

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Species

# %%
#| export
def get_species_lut():
    df = pd.read_excel(species_lut_path(), usecols=['species_id','species'])
    return df.set_index('species_id').to_dict()['species']

# %%
# | export
class LookupSpeciesIdCB(Callback):
    "Lookup MARIS species by species_id."
    def __init__(self,
                 fn_lut=get_species_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            if 'species' in tfm.dfs[k].columns: 
                tfm.dfs[k]['Species'] = tfm.dfs[k]['species'].replace(lut)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB(),
                            LookupSpeciesIdCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ... Latitude degrees  \
#  3             0.000003  3.343000e-07    2      1  ...               68
#  13            0.000014  1.370000e-06    2      1  ...               68
#  14            0.001969  1.969200e-04    2      1  ...               68
#  21            0.001646  1.645800e-04    2      1  ...               68
#  31            0.000002  2.224000e-07    2      1  ...               72
#  ...                ...           ...  ...    ...  ...              ...
#  70595         0.003642  2.414650e-04    2      1  ...               72
#  70605         0.000007  7.249000e-07    2      1  ...               72
#  70609         0.003575  2.377380e-04    2      1  ...               74
#  70619         0.000004  5.670000e-07    2      1  ...               74
#  70624         0.260000  7.280000e-03    2      1  ...               74
#
#        Latitude minutes Latitude seconds  Latitude direction  \
#  3                   48        59.996338                   N
#  13                  48        59.996338                   N
#  14                  48        59.996338                   N
#  21                   6         1.807251                   N
#  31                   6        52.207031                   N
#  ...                ...              ...                 ...
#  70595               30         0.000000                   N
#  70605               30         0.000000                   N
#  70609                0         0.000000                   N
#  70619                0         0.000000                   N
#  70624                0         0.000000                   N
#
#         Longitude degrees  Longitude minutes Longitude seconds  \
#  3                     58                 13         53.999634
#  13                    58                 13         53.999634
#  14                    58                 13         53.999634
#  21                    57                 47         36.596375
#  31                    57                 34         55.202637
#  ...                  ...                ...               ...
#  70595                 40                  0          0.000000
#  70605                 40                  0          0.000000
#  70609                 40                  0          0.000000
#  70619                 40                  0          0.000000
#  70624                 40                  0          0.000000
#
#         Longitude direction   Unit  Value type
#  3                        W  Bq/m3           <
#  13                       W  Bq/m3           <
#  14                       W  Bq/m3           <
#  21                       W  Bq/m3           <
#  31                       W  Bq/m3           <
#  ...                    ...    ...         ...
#  70595                    E  Bq/m3           <
#  70605                    E  Bq/m3           <
#  70609                    E  Bq/m3           <
#  70619                    E  Bq/m3           <
#  70624                    E  Bq/m3           <
#
#  [10090 rows x 23 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Latitude minutes  \
#  1       11474   cs137           0.1800  0.014634  ...                47
#  11       4714   cs137           0.2198  0.025633  ...                 6
#  21       6465   cs137           0.2090  0.008778  ...                17
#  31       6466   cs137           0.1830  0.007503  ...                43
#  41       6143   cs137           0.1696  0.018266  ...                 0
#  ...       ...     ...              ...       ...  ...               ...
#  79921     259   cs137           0.1200  0.013500  ...                25
#  79931    1913   cs137           0.1200  0.020000  ...                25
#  79941     140   cs137           0.0420  0.016500  ...                45
#  79951    1878   cs137           0.1700  0.015000  ...                30
#  79961    1865   cs137           0.1100  0.010000  ...                20
#
#         Latitude seconds Latitude direction Longitude degrees  \
#  1              2.991943                  N                39
#  11            59.993591                  N                39
#  21            22.987061                  N                35
#  31            12.004395                  N                35
#  41             0.000000                  N                34
#  ...                 ...                ...               ...
#  79921         13.009644                  N                34
#  79931         35.009766                  N                34
#  79941         31.997681                  N                35
#  79951         36.007690                  N                36
#  79961          5.996704                  N                36
#
#        Longitude minutes  Longitude seconds  Longitude direction    Unit  \
#  1                    38           4.002686                    W  Bq/kgw
#  11                    9           0.005493                    W  Bq/kgw
#  21                   55          11.993408                    W  Bq/kgw
#  31                    5          59.994507                    W  Bq/kgw
#  41                    0           0.000000                    W  Bq/kgw
#  ...                 ...                ...                  ...     ...
#  79921                20          10.006714                    E  Bq/kgw
#  79931                21           5.995789                    E  Bq/kgw
#  79941                31          19.005432                    E  Bq/kgw
#  79951                34          52.002869                    E  Bq/kgw
#  79961                43          20.999451                    E  Bq/kgw
#
#        Value type                       Species
#  1              <                  Gadus morhua
#  11             <     Hippoglossus hippoglossus
#  21             <                  Gadus morhua
#  31             <              Sebastes marinus
#  41             <                  Gadus morhua
#  ...          ...                           ...
#  79921          <  Hippoglossoides platessoides
#  79931          <  Hippoglossoides platessoides
#  79941          <             Mallotus villosus
#  79951          <                  Gadus morhua
#  79961          <  Hippoglossoides platessoides
#
#  [7997 rows x 26 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Body part

# %%
#| export
def get_bodypart_lut():
    df = pd.read_excel(bodyparts_lut_path(), usecols=['bodypar_id','bodypar'])
    return df.set_index('bodypar_id').to_dict()['bodypar']

# %%
# | export
class LookupBodypartIdCB(Callback):
    "Lookup MARIS bodypart by bodypar_id."
    def __init__(self,
                 fn_lut=get_bodypart_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            if 'body_part' in tfm.dfs[k].columns: 
                tfm.dfs[k]['Body part'] = tfm.dfs[k]['body_part'].replace(lut)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB(),
                            LookupSpeciesIdCB(),
                            LookupBodypartIdCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ... Latitude degrees  \
#  3             0.000003  3.343000e-07    2      1  ...               68
#  13            0.000014  1.370000e-06    2      1  ...               68
#  14            0.001969  1.969200e-04    2      1  ...               68
#  21            0.001646  1.645800e-04    2      1  ...               68
#  31            0.000002  2.224000e-07    2      1  ...               72
#  ...                ...           ...  ...    ...  ...              ...
#  70595         0.003642  2.414650e-04    2      1  ...               72
#  70605         0.000007  7.249000e-07    2      1  ...               72
#  70609         0.003575  2.377380e-04    2      1  ...               74
#  70619         0.000004  5.670000e-07    2      1  ...               74
#  70624         0.260000  7.280000e-03    2      1  ...               74
#
#        Latitude minutes Latitude seconds  Latitude direction  \
#  3                   48        59.996338                   N
#  13                  48        59.996338                   N
#  14                  48        59.996338                   N
#  21                   6         1.807251                   N
#  31                   6        52.207031                   N
#  ...                ...              ...                 ...
#  70595               30         0.000000                   N
#  70605               30         0.000000                   N
#  70609                0         0.000000                   N
#  70619                0         0.000000                   N
#  70624                0         0.000000                   N
#
#         Longitude degrees  Longitude minutes Longitude seconds  \
#  3                     58                 13         53.999634
#  13                    58                 13         53.999634
#  14                    58                 13         53.999634
#  21                    57                 47         36.596375
#  31                    57                 34         55.202637
#  ...                  ...                ...               ...
#  70595                 40                  0          0.000000
#  70605                 40                  0          0.000000
#  70609                 40                  0          0.000000
#  70619                 40                  0          0.000000
#  70624                 40                  0          0.000000
#
#         Longitude direction   Unit  Value type
#  3                        W  Bq/m3           <
#  13                       W  Bq/m3           <
#  14                       W  Bq/m3           <
#  21                       W  Bq/m3           <
#  31                       W  Bq/m3           <
#  ...                    ...    ...         ...
#  70595                    E  Bq/m3           <
#  70605                    E  Bq/m3           <
#  70609                    E  Bq/m3           <
#  70619                    E  Bq/m3           <
#  70624                    E  Bq/m3           <
#
#  [10090 rows x 23 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Latitude seconds  \
#  1       11474   cs137           0.1800  0.014634  ...          2.991943
#  11       4714   cs137           0.2198  0.025633  ...         59.993591
#  21       6465   cs137           0.2090  0.008778  ...         22.987061
#  31       6466   cs137           0.1830  0.007503  ...         12.004395
#  41       6143   cs137           0.1696  0.018266  ...          0.000000
#  ...       ...     ...              ...       ...  ...               ...
#  79921     259   cs137           0.1200  0.013500  ...         13.009644
#  79931    1913   cs137           0.1200  0.020000  ...         35.009766
#  79941     140   cs137           0.0420  0.016500  ...         31.997681
#  79951    1878   cs137           0.1700  0.015000  ...         36.007690
#  79961    1865   cs137           0.1100  0.010000  ...          5.996704
#
#         Latitude direction Longitude degrees Longitude minutes  \
#  1                       N                39                38
#  11                      N                39                 9
#  21                      N                35                55
#  31                      N                35                 5
#  41                      N                34                 0
#  ...                   ...               ...               ...
#  79921                   N                34                20
#  79931                   N                34                21
#  79941                   N                35                31
#  79951                   N                36                34
#  79961                   N                36                43
#
#        Longitude seconds  Longitude direction    Unit  Value type  \
#  1              4.002686                    W  Bq/kgw           <
#  11             0.005493                    W  Bq/kgw           <
#  21            11.993408                    W  Bq/kgw           <
#  31            59.994507                    W  Bq/kgw           <
#  41             0.000000                    W  Bq/kgw           <
#  ...                 ...                  ...     ...         ...
#  79921         10.006714                    E  Bq/kgw           <
#  79931          5.995789                    E  Bq/kgw           <
#  79941         19.005432                    E  Bq/kgw           <
#  79951         52.002869                    E  Bq/kgw           <
#  79961         20.999451                    E  Bq/kgw           <
#
#                              Species                              Body part
#  1                      Gadus morhua                    Flesh without bones
#  11        Hippoglossus hippoglossus                    Flesh without bones
#  21                     Gadus morhua                    Flesh without bones
#  31                 Sebastes marinus                    Flesh without bones
#  41                     Gadus morhua                    Flesh without bones
#  ...                             ...                                    ...
#  79921  Hippoglossoides platessoides                                 Muscle
#  79931  Hippoglossoides platessoides                    Flesh without bones
#  79941             Mallotus villosus  Whole animal eviscerated without head
#  79951                  Gadus morhua                    Flesh without bones
#  79961  Hippoglossoides platessoides                    Flesh without bones
#
#  [7997 rows x 27 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup :  Dry weight & Wet weight

# %%
#|eval: false
'''
# | export
class ConvertWetWeightDryWeightIdCB(Callback):
    "Covert  MARIS bodypart by bodypar_id."
    def __init__(self,
                 fn_lut=get_bodypart_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            if 'body_part' in tfm.dfs[k].columns: 
                tfm.dfs[k]['Body part'] = tfm.dfs[k]['body_part'].replace(lut)
'''
# Out:
# '\n# | export\nclass ConvertWetWeightDryWeightIdCB(Callback):\n    "Covert  MARIS bodypart by bodypar_id."\n    def __init__(self,\n                 fn_lut=get_bodypart_lut):\n        fc.store_attr()\n\n    def __call__(self, tfm):\n        lut = self.fn_lut()\n        for k in tfm.dfs.keys():\n            if \'body_part\' in tfm.dfs[k].columns: \n                tfm.dfs[k][\'Body part\'] = tfm.dfs[k][\'body_part\'].replace(lut)\n'

# %% [markdown]
# ***

# %% [markdown]
# ### Lookup : Sediment type

# %%
#| export
def get_sediments_lut():
    df = pd.read_excel(sediments_lut_path(), usecols=['sedtype_id','sedtype'])
    return df.set_index('sedtype_id').to_dict()['sedtype']

# %%
# | export
class LookupSedimentTypeIdCB(Callback):
    "Lookup MARIS sedtype by sedtype_id."
    def __init__(self,
                 fn_lut=get_bodypart_lut):
        fc.store_attr()

    def __call__(self, tfm):
        lut = self.fn_lut()
        for k in tfm.dfs.keys():
            if 'sed_type' in tfm.dfs[k].columns: 
                tfm.dfs[k]['Sediment type'] = tfm.dfs[k]['sed_type'].replace(lut)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB(),
                            LookupSpeciesIdCB(),
                            LookupBodypartIdCB(),
                            LookupSedimentTypeIdCB()
                            ])
tfm()
# Out:
# {'seawater':              lon        lat  smp_depth        time  sample        nuclide  \
#  3     -58.231667  68.816666        0.0  1339718400   15765  pu239_240_tot
#  13    -58.231667  68.816666        0.0  1339718400   15781           tc99
#  14    -58.231667  68.816666        0.0  1339718400   15799          cs137
#  21    -57.793499  68.100502        0.0  1371168000   15811          cs137
#  31    -57.582001  72.114502        0.0  1339718400   15766  pu239_240_tot
#  ...          ...        ...        ...         ...     ...            ...
#  70595  40.000000  72.500000        0.0   804902400    5973          cs137
#  70605  40.000000  72.500000        0.0   804902400    5985  pu239_240_tot
#  70609  40.000000  74.000000        0.0   804988800    5974          cs137
#  70619  40.000000  74.000000        0.0   804988800    5986  pu239_240_tot
#  70624  40.000000  74.000000        0.0   804988800    5992             h3
#
#         Activity or MDA          _unc  _dl  _unit  ... Latitude degrees  \
#  3             0.000003  3.343000e-07    2      1  ...               68
#  13            0.000014  1.370000e-06    2      1  ...               68
#  14            0.001969  1.969200e-04    2      1  ...               68
#  21            0.001646  1.645800e-04    2      1  ...               68
#  31            0.000002  2.224000e-07    2      1  ...               72
#  ...                ...           ...  ...    ...  ...              ...
#  70595         0.003642  2.414650e-04    2      1  ...               72
#  70605         0.000007  7.249000e-07    2      1  ...               72
#  70609         0.003575  2.377380e-04    2      1  ...               74
#  70619         0.000004  5.670000e-07    2      1  ...               74
#  70624         0.260000  7.280000e-03    2      1  ...               74
#
#        Latitude minutes Latitude seconds  Latitude direction  \
#  3                   48        59.996338                   N
#  13                  48        59.996338                   N
#  14                  48        59.996338                   N
#  21                   6         1.807251                   N
#  31                   6        52.207031                   N
#  ...                ...              ...                 ...
#  70595               30         0.000000                   N
#  70605               30         0.000000                   N
#  70609                0         0.000000                   N
#  70619                0         0.000000                   N
#  70624                0         0.000000                   N
#
#         Longitude degrees  Longitude minutes Longitude seconds  \
#  3                     58                 13         53.999634
#  13                    58                 13         53.999634
#  14                    58                 13         53.999634
#  21                    57                 47         36.596375
#  31                    57                 34         55.202637
#  ...                  ...                ...               ...
#  70595                 40                  0          0.000000
#  70605                 40                  0          0.000000
#  70609                 40                  0          0.000000
#  70619                 40                  0          0.000000
#  70624                 40                  0          0.000000
#
#         Longitude direction   Unit  Value type
#  3                        W  Bq/m3           <
#  13                       W  Bq/m3           <
#  14                       W  Bq/m3           <
#  21                       W  Bq/m3           <
#  31                       W  Bq/m3           <
#  ...                    ...    ...         ...
#  70595                    E  Bq/m3           <
#  70605                    E  Bq/m3           <
#  70609                    E  Bq/m3           <
#  70619                    E  Bq/m3           <
#  70624                    E  Bq/m3           <
#
#  [10090 rows x 23 columns],
#  'biota':              lon        lat        time  bio_group  species  body_part  \
#  1     -39.634445  66.784164  1017014400          4       99         52
#  11    -39.150002  62.116665  1375228800          4      426         52
#  21    -35.919998  64.289719  1287273600          4       99         52
#  31    -35.099998  64.720001  1287100800          4      381         52
#  41    -34.000000  64.000000  1306886400          4       99         52
#  ...          ...        ...         ...        ...      ...        ...
#  79921  34.336113  72.420280  1629676800          4      404         34
#  79931  34.351665  72.426392  1535760000          4      404         52
#  79941  35.521946  78.758888  1632355200          4      402          3
#  79951  36.581112  73.510002  1536537600          4       99         52
#  79961  36.722500  75.334999  1536883200          4      404         52
#
#         sample nuclide  Activity or MDA      _unc  ...  Latitude seconds  \
#  1       11474   cs137           0.1800  0.014634  ...          2.991943
#  11       4714   cs137           0.2198  0.025633  ...         59.993591
#  21       6465   cs137           0.2090  0.008778  ...         22.987061
#  31       6466   cs137           0.1830  0.007503  ...         12.004395
#  41       6143   cs137           0.1696  0.018266  ...          0.000000
#  ...       ...     ...              ...       ...  ...               ...
#  79921     259   cs137           0.1200  0.013500  ...         13.009644
#  79931    1913   cs137           0.1200  0.020000  ...         35.009766
#  79941     140   cs137           0.0420  0.016500  ...         31.997681
#  79951    1878   cs137           0.1700  0.015000  ...         36.007690
#  79961    1865   cs137           0.1100  0.010000  ...          5.996704
#
#         Latitude direction Longitude degrees Longitude minutes  \
#  1                       N                39                38
#  11                      N                39                 9
#  21                      N                35                55
#  31                      N                35                 5
#  41                      N                34                 0
#  ...                   ...               ...               ...
#  79921                   N                34                20
#  79931                   N                34                21
#  79941                   N                35                31
#  79951                   N                36                34
#  79961                   N                36                43
#
#        Longitude seconds  Longitude direction    Unit  Value type  \
#  1              4.002686                    W  Bq/kgw           <
#  11             0.005493                    W  Bq/kgw           <
#  21            11.993408                    W  Bq/kgw           <
#  31            59.994507                    W  Bq/kgw           <
#  41             0.000000                    W  Bq/kgw           <
#  ...                 ...                  ...     ...         ...
#  79921         10.006714                    E  Bq/kgw           <
#  79931          5.995789                    E  Bq/kgw           <
#  79941         19.005432                    E  Bq/kgw           <
#  79951         52.002869                    E  Bq/kgw           <
#  79961         20.999451                    E  Bq/kgw           <
#
#                              Species                              Body part
#  1                      Gadus morhua                    Flesh without bones
#  11        Hippoglossus hippoglossus                    Flesh without bones
#  21                     Gadus morhua                    Flesh without bones
#  31                 Sebastes marinus                    Flesh without bones
#  41                     Gadus morhua                    Flesh without bones
#  ...                             ...                                    ...
#  79921  Hippoglossoides platessoides                                 Muscle
#  79931  Hippoglossoides platessoides                    Flesh without bones
#  79941             Mallotus villosus  Whole animal eviscerated without head
#  79951                  Gadus morhua                    Flesh without bones
#  79961  Hippoglossoides platessoides                    Flesh without bones
#
#  [7997 rows x 27 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Rename columns

# %%
#| export
# Define columns of interest (keys) and renaming rules (values).
renaming_rules = {('seawater','biota', 'sediment') : {    
                                                        ## DEFAULT
                                                        'Sample type' : 'Sample type',
                                                        'Latitude degrees' : 'Latitude degrees',
                                                        'Latitude minutes' : 'Latitude minutes',
                                                        'Latitude seconds' : 'Latitude seconds',
                                                        'Latitude direction' : 'Latitude direction',
                                                        'Longitude degrees' : 'Longitude degrees',
                                                        'Longitude minutes' : 'Longitude minutes',
                                                        'Longitude seconds' : 'Longitude seconds', 
                                                        'Longitude direction' : 'Longitude direction',    
                                                        'lat' : 'Latitude decimal' ,
                                                        'lon' : 'Longitude decimal',
                                                        'Sampling start date': 'Sampling start date',
                                                        #'Sampling start time' : 'Sampling start time'',
                                                        #'Sampling end date' : 'Sampling end date',
                                                        #'Sampling end time' : 'Sampling end time',
                                                        'Nuclide': 'Nuclide',
                                                        'Value type': 'Value type',
                                                        'Unit' : 'Unit',
                                                        'Activity or MDA' : 'Activity or MDA',
                                                        '_unc' : 'Uncertainty',
                                                        #'Quality flag' : 'Quality flag'
                                                        #'Station ID' : 'Station ID '
                                                        #'Sample ID' : 'Sample ID'
                                                        #'Profile or transect ID' : 'Profile or transect ID'
                                                        #'Sampling method' : 'Sampling method'
                                                        #'Preparation method' : 'Preparation method'
                                                        #'Counting method' : 'Counting method'
                                                        #'Sample notes' : 'Sample notes'
                                                        #'Measurement notes' : 'Measurement notes'
                                                    },
                  ('seawater',) : {
                                ## SEAWATER
                                #'smp_depth': 'Sampling depth',
                                #'Salinity' : 'Salinity',
                                #'Temperature' : 'Temperature',
                                #'Filtered' : 'Filtered',
                                #'Mesh size' : 'Mesh size',
                                #'Total depth' : 'Total depth'
                                },
                  ('biota', 'sediment') : {
                                            ## BIOTA & SEDIMENT
                                            #'Dry weight' : 'Dry weight',
                                            #'Wet weight' : 'Wet weight',
                                            #'Dry/wet ratio' : 'Dry/wet ratio',
                                            #'Drying method' : 'Drying method'
                                            },
                  ('biota',) : { 
                                ## BIOTA
                                'Species' : 'Species',
                                'Body part' : 'Body part'
                                },
                  ('sediment',) : {
                                ## SEDIMENT
                                #'Top' : 'Top',
                                #'Bottom' : 'Bottom',
                                #'Sediment type' : 'Sediment type'
                                }
                    }

# %%
#| export
class RenameColumnCB(Callback):
    def __init__(self,
                 renaming_rules=renaming_rules):
        fc.store_attr()

    def __call__(self, tfm):
        for grp in tfm.dfs.keys():
            # Get list of renaming rules keys for the group of interest
            rules_of_interest=[key for key in self.renaming_rules.keys() if grp in key]
            # Merge the dictionaries
            rules={k: v for d in [self.renaming_rules[key] for key in rules_of_interest] for k, v in d.items()}
            # Select cols of interest
            tfm.dfs[grp] = tfm.dfs[grp].loc[:,list(rules.keys())]
            # Rename cols
            tfm.dfs[grp].rename(columns=rules, inplace=True)

# %%
#|eval: false
dfs = netcdf4_to_df(fname_in)
tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB(),
                            LookupSpeciesIdCB(),
                            LookupBodypartIdCB(),
                            LookupSedimentTypeIdCB(),
                            RenameColumnCB()
                            ])
tfm()
# Out:
# {'seawater':       Sample type  Latitude degrees  Latitude minutes  Latitude seconds  \
#  3        SEAWATER                68                48         59.996338
#  13       SEAWATER                68                48         59.996338
#  14       SEAWATER                68                48         59.996338
#  21       SEAWATER                68                 6          1.807251
#  31       SEAWATER                72                 6         52.207031
#  ...           ...               ...               ...               ...
#  70595    SEAWATER                72                30          0.000000
#  70605    SEAWATER                72                30          0.000000
#  70609    SEAWATER                74                 0          0.000000
#  70619    SEAWATER                74                 0          0.000000
#  70624    SEAWATER                74                 0          0.000000
#
#        Latitude direction  Longitude degrees  Longitude minutes  \
#  3                      N                 58                 13
#  13                     N                 58                 13
#  14                     N                 58                 13
#  21                     N                 57                 47
#  31                     N                 57                 34
#  ...                  ...                ...                ...
#  70595                  N                 40                  0
#  70605                  N                 40                  0
#  70609                  N                 40                  0
#  70619                  N                 40                  0
#  70624                  N                 40                  0
#
#         Longitude seconds Longitude direction  Latitude decimal  \
#  3              53.999634                   W         68.816666
#  13             53.999634                   W         68.816666
#  14             53.999634                   W         68.816666
#  21             36.596375                   W         68.100502
#  31             55.202637                   W         72.114502
#  ...                  ...                 ...               ...
#  70595           0.000000                   E         72.500000
#  70605           0.000000                   E         72.500000
#  70609           0.000000                   E         74.000000
#  70619           0.000000                   E         74.000000
#  70624           0.000000                   E         74.000000
#
#         Longitude decimal Sampling start date    Nuclide Value type   Unit  \
#  3             -58.231667         15-Jun-2012  239_240Pu          <  Bq/m3
#  13            -58.231667         15-Jun-2012       99Tc          <  Bq/m3
#  14            -58.231667         15-Jun-2012      137Cs          <  Bq/m3
#  21            -57.793499         14-Jun-2013      137Cs          <  Bq/m3
#  31            -57.582001         15-Jun-2012  239_240Pu          <  Bq/m3
#  ...                  ...                 ...        ...        ...    ...
#  70595          40.000000         05-Jul-1995      137Cs          <  Bq/m3
#  70605          40.000000         05-Jul-1995  239_240Pu          <  Bq/m3
#  70609          40.000000         06-Jul-1995      137Cs          <  Bq/m3
#  70619          40.000000         06-Jul-1995  239_240Pu          <  Bq/m3
#  70624          40.000000         06-Jul-1995         3H          <  Bq/m3
#
#         Activity or MDA   Uncertainty
#  3             0.000003  3.343000e-07
#  13            0.000014  1.370000e-06
#  14            0.001969  1.969200e-04
#  21            0.001646  1.645800e-04
#  31            0.000002  2.224000e-07
#  ...                ...           ...
#  70595         0.003642  2.414650e-04
#  70605         0.000007  7.249000e-07
#  70609         0.003575  2.377380e-04
#  70619         0.000004  5.670000e-07
#  70624         0.260000  7.280000e-03
#
#  [10090 rows x 17 columns],
#  'biota':       Sample type  Latitude degrees  Latitude minutes  Latitude seconds  \
#  1           BIOTA                66                47          2.991943
#  11          BIOTA                62                 6         59.993591
#  21          BIOTA                64                17         22.987061
#  31          BIOTA                64                43         12.004395
#  41          BIOTA                64                 0          0.000000
#  ...           ...               ...               ...               ...
#  79921       BIOTA                72                25         13.009644
#  79931       BIOTA                72                25         35.009766
#  79941       BIOTA                78                45         31.997681
#  79951       BIOTA                73                30         36.007690
#  79961       BIOTA                75                20          5.996704
#
#        Latitude direction  Longitude degrees  Longitude minutes  \
#  1                      N                 39                 38
#  11                     N                 39                  9
#  21                     N                 35                 55
#  31                     N                 35                  5
#  41                     N                 34                  0
#  ...                  ...                ...                ...
#  79921                  N                 34                 20
#  79931                  N                 34                 21
#  79941                  N                 35                 31
#  79951                  N                 36                 34
#  79961                  N                 36                 43
#
#         Longitude seconds Longitude direction  Latitude decimal  \
#  1               4.002686                   W         66.784164
#  11              0.005493                   W         62.116665
#  21             11.993408                   W         64.289719
#  31             59.994507                   W         64.720001
#  41              0.000000                   W         64.000000
#  ...                  ...                 ...               ...
#  79921          10.006714                   E         72.420280
#  79931           5.995789                   E         72.426392
#  79941          19.005432                   E         78.758888
#  79951          52.002869                   E         73.510002
#  79961          20.999451                   E         75.334999
#
#         Longitude decimal Sampling start date Nuclide Value type    Unit  \
#  1             -39.634445         25-Mar-2002   137Cs          <  Bq/kgw
#  11            -39.150002         31-Jul-2013   137Cs          <  Bq/kgw
#  21            -35.919998         17-Oct-2010   137Cs          <  Bq/kgw
#  31            -35.099998         15-Oct-2010   137Cs          <  Bq/kgw
#  41            -34.000000         01-Jun-2011   137Cs          <  Bq/kgw
#  ...                  ...                 ...     ...        ...     ...
#  79921          34.336113         23-Aug-2021   137Cs          <  Bq/kgw
#  79931          34.351665         01-Sep-2018   137Cs          <  Bq/kgw
#  79941          35.521946         23-Sep-2021   137Cs          <  Bq/kgw
#  79951          36.581112         10-Sep-2018   137Cs          <  Bq/kgw
#  79961          36.722500         14-Sep-2018   137Cs          <  Bq/kgw
#
#         Activity or MDA  Uncertainty                       Species  \
#  1               0.1800     0.014634                  Gadus morhua
#  11              0.2198     0.025633     Hippoglossus hippoglossus
#  21              0.2090     0.008778                  Gadus morhua
#  31              0.1830     0.007503              Sebastes marinus
#  41              0.1696     0.018266                  Gadus morhua
#  ...                ...          ...                           ...
#  79921           0.1200     0.013500  Hippoglossoides platessoides
#  79931           0.1200     0.020000  Hippoglossoides platessoides
#  79941           0.0420     0.016500             Mallotus villosus
#  79951           0.1700     0.015000                  Gadus morhua
#  79961           0.1100     0.010000  Hippoglossoides platessoides
#
#                                     Body part
#  1                        Flesh without bones
#  11                       Flesh without bones
#  21                       Flesh without bones
#  31                       Flesh without bones
#  41                       Flesh without bones
#  ...                                      ...
#  79921                                 Muscle
#  79931                    Flesh without bones
#  79941  Whole animal eviscerated without head
#  79951                    Flesh without bones
#  79961                    Flesh without bones
#
#  [7997 rows x 19 columns]}

# %% [markdown]
# ***

# %% [markdown]
# ### Encoding

# %%
#| export
def encode(fname_in, fname_out, ref_id=-1, **kwargs):
    dfs = netcdf4_to_df(fname_in)
    tfm = Transformer(dfs, cbs=[ReshapeWideToLong(),
                            ParseTimeCB(cfg()),
                            LookupSampleType(),
                            LookupNuclideIdCB(),
                            ConvertLonLatCB(), 
                            LookupUnitIdCB(),
                            LookupValueTypeIdCB(),
                            LookupSpeciesIdCB(),
                            LookupBodypartIdCB(),
                            LookupSedimentTypeIdCB(),
                            RenameColumnCB()
                            ])
    
    encoder = OpenRefineCsvEncoder(tfm(), 
                            dest_fname=fname_out,
                            ref_id = ref_id,
                            **kwargs)
    encoder.encode()
    return encoder

# %%
encode(fname_in, fname_out, ref_id, verbose=False)

# %% [markdown]
# TODO Review nuclides. Cs127?

# %% [markdown]
# TODO: check the dfs as the dimensions should be longer. this means each row has a single nuclide. Is this what we want?

# %% [markdown]
# TODO: Include refid in encoder

# %% [markdown]
# TODO HELCOM seawater is missing depth

# %% [markdown]
# TODO Check : OSPAR weight missing in netcdf?

# %% [markdown]
# TODO: Should the var be called 'detection limit'? Is 'value type' more appropriate?

# %% [markdown]
# TODO Biogroup not used in OPEN REfINE csv format. Confirm this

# %% [markdown]
# TODO Ask about Species dbo. Paul said there is a larger one.

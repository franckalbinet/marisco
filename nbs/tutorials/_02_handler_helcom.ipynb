# %% [markdown]
# # HELCOM dataset
# > Importing, cleaning and transforming HELCOM data ([source](https://helcom.fi/about-us))

# %% [markdown]
# ## Packages import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from netCDF4 import Dataset
from datetime import datetime
from cftime import num2date, date2num
import re
import glob
from pathlib import Path

# %% [markdown]
# ## Data reading

# %% [markdown]
# The data is provided as a Microsoft Access `.accdb` database file.

# %%
src_dir = '../../_data/accdb/mors/csv'

# %% [markdown]
# ### Database overview

# %%
for file in glob.glob(src_dir + '/*.csv'):
    print(80*'-')
    print(f'{Path(file).name}')
    print(80*'-', '\n')
    df = pd.read_csv(file)
    print(f'Columns: {df.columns.values}\n')
    print(df.info(), '\n')
    print(df.head(), '\n')
    #with open(file, 'rb') as f: 
    #    dumps.append(pickle.load(f))
# Out:
# --------------------------------------------------------------------------------
# NUCLIDE.csv
# --------------------------------------------------------------------------------
#
# Columns: ['NUCLIDE' 'NUCLIDE_NAME' 'CLASSIFICATION' 'WEIGHT']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NUCLIDE         68 non-null     object
#  1   NUCLIDE_NAME    68 non-null     object
#  2   CLASSIFICATION  10 non-null     object
#  3   WEIGHT          0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 2.2+ KB
# None
#
#   NUCLIDE   NUCLIDE_NAME CLASSIFICATION  WEIGHT
# 0   AC228   Actinium-228            NaN     NaN
# 1  AG108M     Silver-108            NaN     NaN
# 2  AG110M     Silver-110            NaN     NaN
# 3   AM241  Americium-241            NaN     NaN
# 4   BA140     Barium-140            NaN     NaN
#
# --------------------------------------------------------------------------------
# MORS_SUBBASIN.csv
# --------------------------------------------------------------------------------
#
# Columns: ['BASINNAME' 'ABREVIATION' 'BASIN' 'BASIN_RANK' 'BASIN_INDICATOR'
#  'BASIN_INDICATOR_NAME']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   BASINNAME             16 non-null     object
#  1   ABREVIATION           16 non-null     object
#  2   BASIN                 16 non-null     int64
#  3   BASIN_RANK            16 non-null     int64
#  4   BASIN_INDICATOR       14 non-null     float64
#  5   BASIN_INDICATOR_NAME  16 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 896.0+ bytes
# None
#
#                    BASINNAME ABREVIATION  BASIN  BASIN_RANK  BASIN_INDICATOR  \
# 0  ARCHIPELAGO AND ÅLAND SEA         ARC      1           3             10.0
# 1                 ARKONA SEA         ARS      2          11              8.0
# 2     NORTHERN BALTIC PROPER         NOB      3           5              4.0
# 3     SOUTHERN BALTIC PROPER         SOB      4           9              7.0
# 4                   BELT SEA         BES      5          12              8.0
#
#                BASIN_INDICATOR_NAME
# 0         ARCHIPELAGO AND ÅLAND SEA
# 1        ARKONA, SOUND AND BELT SEA
# 2            NORTHERN BALTIC PROPER
# 3  BORNHOLM SEA AND SOUTHERN BALTIC
# 4        ARKONA, SOUND AND BELT SEA
#
# --------------------------------------------------------------------------------
# SEDIMENT_TYPE.csv
# --------------------------------------------------------------------------------
#
# Columns: ['SEDI' 'SEDIMENT TYPE' 'RECOMMENDED TO BE USED']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SEDI                    47 non-null     int64
#  1   SEDIMENT TYPE           47 non-null     object
#  2   RECOMMENDED TO BE USED  46 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ KB
# None
#
#    SEDI    SEDIMENT TYPE RECOMMENDED TO BE USED
# 0   -99          NO DATA                    NaN
# 1    30  SILT AND GRAVEL                    YES
# 2     0           GRAVEL                    YES
# 3     1             SAND                    YES
# 4     2        FINE SAND                     NO
#
# --------------------------------------------------------------------------------
# NUCLIDEMON.csv
# --------------------------------------------------------------------------------
#
# Columns: ['NUCLIDE_ID' 'NUCLIDE' 'EMITTER' 'GAMMA IDENTIFIER' 'NATURALITY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NUCLIDE_ID        52 non-null     int64
#  1   NUCLIDE           52 non-null     object
#  2   EMITTER           22 non-null     object
#  3   GAMMA IDENTIFIER  51 non-null     object
#  4   NATURALITY        51 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB
# None
#
#    NUCLIDE_ID NUCLIDE EMITTER GAMMA IDENTIFIER NATURALITY
# 0           1   AC228     NaN                Y          Y
# 1           2  AG108M     NaN                Y          N
# 2           3  AG110M     NaN                Y          N
# 3           4   AM241       A                Y          N
# 4           5   BA140     NaN                Y          N
#
# --------------------------------------------------------------------------------
# TISSUE.csv
# --------------------------------------------------------------------------------
#
# Columns: ['TISSUE' 'TISSUE_DESCRIPTION']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TISSUE              29 non-null     int64
#  1   TISSUE_DESCRIPTION  29 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 592.0+ bytes
# None
#
#    TISSUE                    TISSUE_DESCRIPTION
# 0       1                            WHOLE FISH
# 1       2           WHOLE FISH WITHOUT ENTRAILS
# 2       3  WHOLE FISH WITHOUT HEAD AND ENTRAILS
# 3       4                      FLESH WITH BONES
# 4       5          FLESH WITHOUT BONES (FILETS)
#
# --------------------------------------------------------------------------------
# HELCOM_SUBBASIN.csv
# --------------------------------------------------------------------------------
#
# Columns: ['BASINNAME' 'HELCOM_SUBBASIN' 'HELCOM-ID']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BASINNAME        19 non-null     object
#  1   HELCOM_SUBBASIN  19 non-null     int64
#  2   HELCOM-ID        17 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 584.0+ bytes
# None
#
#                 BASINNAME  HELCOM_SUBBASIN  HELCOM-ID
# 0               Aland Sea                1       14.0
# 1            Arkona Basin                2        6.0
# 2  Northern Baltic Proper                3       12.0
# 3            Gdansk Basin                4        8.0
# 4              Great Belt                5        2.0
#
# --------------------------------------------------------------------------------
# ANALYSIS_METHOD.csv
# --------------------------------------------------------------------------------
#
# Columns: ['METHOD' 'COUNTRY' 'DESCRIPTION']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   METHOD       88 non-null     object
#  1   COUNTRY      88 non-null     int64
#  2   DESCRIPTION  88 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB
# None
#
#    METHOD  COUNTRY                                        DESCRIPTION
# 0  BFFG01        6  Gammaspectrometric analysis with Germanium det...
# 1  BFFG02        6  Sr-90, a) Y-90 extraction method dried ash and...
# 2  CLOR02       67  Radiochemical method Radiocaesium separation f...
# 3  CLOR03       67  Radiochem. meth.-134+137Cs was measured after ...
# 4  CLOR04       67  Radiochem. meth of Sr90. Precipation with oxal...
#
# --------------------------------------------------------------------------------
# BIOTA_NAME.csv
# --------------------------------------------------------------------------------
#
# Columns: ['BIOTATYPE' 'BIOTA_NAME']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BIOTATYPE   3 non-null      object
#  1   BIOTA_NAME  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# None
#
#   BIOTATYPE      BIOTA_NAME
# 0         F            FISH
# 1         P           PLANT
# 2         B  BENTHIC ANIMAL
#
# --------------------------------------------------------------------------------
# DEVICE_NAME.csv
# --------------------------------------------------------------------------------
#
# Columns: ['DEVICE' 'DEVICE_NAME' 'COUNTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DEVICE       54 non-null     object
#  1   DEVICE_NAME  49 non-null     object
#  2   COUNTRY      43 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ KB
# None
#
#   DEVICE     DEVICE_NAME  COUNTRY
# 0      1  NIEMISTÖ CORER      NaN
# 1     10     not defined      NaN
# 2     11     not defined      NaN
# 3      2       BOX CORER      NaN
# 4     21     not defined      NaN
#
# --------------------------------------------------------------------------------
# SED02.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'NUCLIDE' 'METHOD' '< VALUE_Bq/kg' 'VALUE_Bq/kg' 'ERROR%_kg'
#  '< VALUE_Bq/m²' 'VALUE_Bq/m²' 'ERROR%_m²' 'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37347 entries, 0 to 37346
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   KEY            37347 non-null  object
#  1   NUCLIDE        37347 non-null  object
#  2   METHOD         36105 non-null  object
#  3   < VALUE_Bq/kg  1768 non-null   object
#  4   VALUE_Bq/kg    37090 non-null  float64
#  5   ERROR%_kg      33557 non-null  float64
#  6   < VALUE_Bq/m²  552 non-null    object
#  7   VALUE_Bq/m²    26780 non-null  float64
#  8   ERROR%_m²      4550 non-null   float64
#  9   DATE_OF_ENTRY  13666 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 2.8+ MB
# None
#
#             KEY NUCLIDE METHOD < VALUE_Bq/kg  VALUE_Bq/kg  ERROR%_kg  \
# 0  SKRIL2012048   RA226    NaN           NaN         35.0       26.0
# 1  SKRIL2012049   RA226    NaN           NaN         36.0       22.0
# 2  SKRIL2012050   RA226    NaN           NaN         38.0       24.0
# 3  SKRIL2012051   RA226    NaN           NaN         36.0       25.0
# 4  SKRIL2012052   RA226    NaN           NaN         30.0       23.0
#
#   < VALUE_Bq/m²  VALUE_Bq/m²  ERROR%_m²      DATE_OF_ENTRY
# 0           NaN          NaN        NaN  08/20/14 00:00:00
# 1           NaN          NaN        NaN  08/20/14 00:00:00
# 2           NaN          NaN        NaN  08/20/14 00:00:00
# 3           NaN          NaN        NaN  08/20/14 00:00:00
# 4           NaN          NaN        NaN  08/20/14 00:00:00
#
# --------------------------------------------------------------------------------
# RUBIN_NAME.csv
# --------------------------------------------------------------------------------
#
# Columns: ['RUBIN_ID' 'RUBIN' 'SCIENTIFIC NAME' 'ENGLISH NAME']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RUBIN_ID         43 non-null     int64
#  1   RUBIN            43 non-null     object
#  2   SCIENTIFIC NAME  43 non-null     object
#  3   ENGLISH NAME     43 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.5+ KB
# None
#
#    RUBIN_ID     RUBIN    SCIENTIFIC NAME     ENGLISH NAME
# 0        11  ABRA BRA      ABRAMIS BRAMA            BREAM
# 1        12  ANGU ANG  ANGUILLA ANGUILLA              EEL
# 2        13  ARCT ISL  ARCTICA ISLANDICA   ISLAND CYPRINE
# 3        14  ASTE RUB    ASTERIAS RUBENS  COMMON STARFISH
# 4        15  CARD EDU      CARDIUM EDULE           COCKLE
#
# --------------------------------------------------------------------------------
# SED01.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'COUNTRY' 'LABORATORY' 'SEQUENCE' 'DATE' 'YEAR' 'MONTH' 'DAY'
#  'STATION' 'LATITUDE (ddmmmm)' 'LATITUDE (dddddd)' 'LONGITUDE (ddmmmm)'
#  'LONGITUDE (dddddd)' 'DEVICE' 'TDEPTH' 'UPPSLI' 'LOWSLI' 'AREA' 'SEDI'
#  'OXIC' 'DW%' 'LOI%' 'MORS_SUBBASIN' 'HELCOM_SUBBASIN' 'SUM_LINK'
#  'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12752 entries, 0 to 12751
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   KEY                 12752 non-null  object
#  1   COUNTRY             12716 non-null  float64
#  2   LABORATORY          12752 non-null  object
#  3   SEQUENCE            12752 non-null  int64
#  4   DATE                12570 non-null  object
#  5   YEAR                12752 non-null  int64
#  6   MONTH               12752 non-null  int64
#  7   DAY                 12625 non-null  float64
#  8   STATION             12728 non-null  object
#  9   LATITUDE (ddmmmm)   12752 non-null  float64
#  10  LATITUDE (dddddd)   12752 non-null  float64
#  11  LONGITUDE (ddmmmm)  12752 non-null  float64
#  12  LONGITUDE (dddddd)  12752 non-null  float64
#  13  DEVICE              12504 non-null  object
#  14  TDEPTH              12710 non-null  float64
#  15  UPPSLI              12744 non-null  float64
#  16  LOWSLI              12743 non-null  float64
#  17  AREA                12752 non-null  float64
#  18  SEDI                12426 non-null  float64
#  19  OXIC                10632 non-null  object
#  20  DW%                 7814 non-null   float64
#  21  LOI%                2810 non-null   float64
#  22  MORS_SUBBASIN       12752 non-null  int64
#  23  HELCOM_SUBBASIN     12752 non-null  int64
#  24  SUM_LINK            9063 non-null   object
#  25  DATE_OF_ENTRY       4458 non-null   object
# dtypes: float64(13), int64(5), object(8)
# memory usage: 2.5+ MB
# None
#
#             KEY  COUNTRY LABORATORY  SEQUENCE               DATE  YEAR  MONTH  \
# 0  SCLOR1984001     67.0       CLOR   1984001  06/03/84 00:00:00  1984      6
# 1  SCLOR1984002     67.0       CLOR   1984002  06/03/84 00:00:00  1984      6
# 2  SCLOR1984003     67.0       CLOR   1984003  06/03/84 00:00:00  1984      6
# 3  SCLOR1984004     67.0       CLOR   1984004  06/03/84 00:00:00  1984      6
# 4  SCLOR1984005     67.0       CLOR   1984005  06/03/84 00:00:00  1984      6
#
#    DAY STATION  LATITUDE (ddmmmm)  ...  LOWSLI   AREA  SEDI OXIC  DW%  LOI%  \
# 0  3.0     B12               54.2  ...     5.0  0.005 -99.0  NaN  NaN   NaN
# 1  3.0     B12               54.2  ...    10.0  0.005 -99.0  NaN  NaN   NaN
# 2  3.0     B12               54.2  ...    15.0  0.005 -99.0  NaN  NaN   NaN
# 3  3.0     B12               54.2  ...    20.0  0.005 -99.0  NaN  NaN   NaN
# 4  3.0     B12               54.2  ...    25.0  0.005 -99.0  NaN  NaN   NaN
#
#    MORS_SUBBASIN  HELCOM_SUBBASIN  SUM_LINK DATE_OF_ENTRY
# 0              2                6         a           NaN
# 1              2                6         a           NaN
# 2              2                6         a           NaN
# 3              2                6         a           NaN
# 4              2                6         a           NaN
#
# [5 rows x 26 columns]
#
# --------------------------------------------------------------------------------
# COUNTRY.csv
# --------------------------------------------------------------------------------
#
# Columns: ['COUNTRYNAME' 'COUNTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   COUNTRYNAME  10 non-null     object
#  1   COUNTRY      10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 288.0+ bytes
# None
#
#   COUNTRYNAME  COUNTRY
# 0     GERMANY        6
# 1     DENMARK       26
# 2     FINLAND       34
# 3      POLAND       67
# 4      SWEDEN       77
#
# --------------------------------------------------------------------------------
# BIO02.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'NUCLIDE' 'METHOD' '< VALUE_Bq/kg' 'VALUE_Bq/kg' 'BASIS' 'ERROR%'
#  'NUMBER' 'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14893 entries, 0 to 14892
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   KEY            14893 non-null  object
#  1   NUCLIDE        14893 non-null  object
#  2   METHOD         14887 non-null  object
#  3   < VALUE_Bq/kg  3159 non-null   object
#  4   VALUE_Bq/kg    14873 non-null  float64
#  5   BASIS          14826 non-null  object
#  6   ERROR%         13842 non-null  float64
#  7   NUMBER         5485 non-null   float64
#  8   DATE_OF_ENTRY  3984 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 1.0+ MB
# None
#
#             KEY   NUCLIDE  METHOD < VALUE_Bq/kg  VALUE_Bq/kg BASIS  ERROR%  \
# 0  BVTIG2012041  CS134     VTIG01             <     0.010140     W     NaN
# 1  BVTIG2012041  K40       VTIG01                 135.300000     W    3.57
# 2  BVTIG2012041  CO60      VTIG01             <     0.013980     W     NaN
# 3  BVTIG2012041  CS137     VTIG01                   4.338000     W    3.48
# 4  BVTIG2012040  CS134     VTIG01             <     0.009614     W     NaN
#
#    NUMBER      DATE_OF_ENTRY
# 0     NaN  02/27/14 00:00:00
# 1     NaN  02/27/14 00:00:00
# 2     NaN  02/27/14 00:00:00
# 3     NaN  02/27/14 00:00:00
# 4     NaN  02/27/14 00:00:00
#
# --------------------------------------------------------------------------------
# BIO01.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'COUNTRY' 'LABORATORY' 'SEQUENCE' 'DATE' 'YEAR' 'MONTH' 'DAY'
#  'STATION' 'LATITUDE ddmmmm' 'LATITUDE dddddd' 'LONGITUDE ddmmmm'
#  'LONGITUDE dddddd' 'SDEPTH' 'RUBIN' 'BIOTATYPE' 'TISSUE' 'NO' 'LENGTH'
#  'WEIGHT' 'DW%' 'LOI%' 'MORS_SUBBASIN' 'HELCOM_SUBBASIN' 'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4314 entries, 0 to 4313
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   KEY               4314 non-null   object
#  1   COUNTRY           4299 non-null   float64
#  2   LABORATORY        4314 non-null   object
#  3   SEQUENCE          4314 non-null   int64
#  4   DATE              4287 non-null   object
#  5   YEAR              4314 non-null   int64
#  6   MONTH             4312 non-null   float64
#  7   DAY               4312 non-null   float64
#  8   STATION           4141 non-null   object
#  9   LATITUDE ddmmmm   4314 non-null   float64
#  10  LATITUDE dddddd   4314 non-null   float64
#  11  LONGITUDE ddmmmm  4314 non-null   float64
#  12  LONGITUDE dddddd  4314 non-null   float64
#  13  SDEPTH            3944 non-null   float64
#  14  RUBIN             4314 non-null   object
#  15  BIOTATYPE         4314 non-null   object
#  16  TISSUE            4314 non-null   int64
#  17  NO                2829 non-null   float64
#  18  LENGTH            4079 non-null   float64
#  19  WEIGHT            2793 non-null   float64
#  20  DW%               3134 non-null   float64
#  21  LOI%              3854 non-null   float64
#  22  MORS_SUBBASIN     4314 non-null   int64
#  23  HELCOM_SUBBASIN   4314 non-null   int64
#  24  DATE_OF_ENTRY     1431 non-null   object
# dtypes: float64(13), int64(5), object(7)
# memory usage: 842.7+ KB
# None
#
#             KEY  COUNTRY LABORATORY  SEQUENCE               DATE  YEAR  MONTH  \
# 0  BBFFG1986001      6.0       BFFG   1986001  12/06/86 00:00:00  1986   12.0
# 1  BBFFG1986002      6.0       BFFG   1986002  12/06/86 00:00:00  1986   12.0
# 2  BBFFG1986003      6.0       BFFG   1986003  12/07/86 00:00:00  1986   12.0
# 3  BBFFG1986004      6.0       BFFG   1986004  12/07/86 00:00:00  1986   12.0
# 4  BBFFG1986005      6.0       BFFG   1986005  12/08/86 00:00:00  1986   12.0
#
#    DAY STATION  LATITUDE ddmmmm  ...  BIOTATYPE  TISSUE  NO  LENGTH WEIGHT  \
# 0  6.0  BKIBU1            54.32  ...          F       5 NaN    39.0    NaN
# 1  6.0   86/ 3            54.29  ...          F       5 NaN    63.0    NaN
# 2  7.0  BKIBU1            54.37  ...          F       5 NaN    56.0    NaN
# 3  7.0  BKIBU1            54.36  ...          F       5 NaN    66.0    NaN
# 4  8.0   BARC2            54.58  ...          F       5 NaN    49.0    NaN
#
#      DW%  LOI%  MORS_SUBBASIN  HELCOM_SUBBASIN  DATE_OF_ENTRY
# 0  20.83  92.8              5               15            NaN
# 1  19.53  92.7              5               15            NaN
# 2  20.04  92.6              5               15            NaN
# 3  18.05  91.3              5               15            NaN
# 4  21.05  92.5              2                2            NaN
#
# [5 rows x 25 columns]
#
# --------------------------------------------------------------------------------
# ICES_AREA.csv
# --------------------------------------------------------------------------------
#
# Columns: ['AREA/ICES' 'STATION']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AREA/ICES  24 non-null     object
#  1   STATION    24 non-null     object
# dtypes: object(2)
# memory usage: 512.0+ bytes
# None
#
#   AREA/ICES STATION
# 0       B01  BKIBU1
# 1       B03  BBHOL3
# 2       B05  BBHOL5
# 3       B09  BROZE9
# 4       B10  BARC10
#
# --------------------------------------------------------------------------------
# LABORATORY_NAME.csv
# --------------------------------------------------------------------------------
#
# Columns: ['LABORATORY' 'LABORATORY_NAME' 'START_DATE' 'END_DATE' 'COUNTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LABORATORY       20 non-null     object
#  1   LABORATORY_NAME  20 non-null     object
#  2   START_DATE       19 non-null     object
#  3   END_DATE         9 non-null      object
#  4   COUNTRY          20 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 928.0+ bytes
# None
#
#   LABORATORY                                    LABORATORY_NAME  \
# 0       BFFG      BUNDESFORSCHUNGANSTALT FÜR FISCHEREI, GERMANY
# 1       CLOR  CENTRAL  LABORATORY  FOR  RADIOLOGICAL PROTECT...
# 2       DHIG  FEDERAL MARITIME AND HYDROGRAPHIC AGENCY, GERMANY
# 3       EBRS  RADIATION SAFETY DEPARTMENT ENVIRONMENTAL BOAR...
# 4       EMHI  ESTONIAN METEOROLOGICAL AND HYDROLOGICAL INSTI...
#
#           START_DATE           END_DATE  COUNTRY
# 0  01/01/86 00:00:00  12/31/07 00:00:00        6
# 1  01/01/84 00:00:00                NaN       67
# 2  01/01/84 00:00:00                NaN        6
# 3  01/01/10 00:00:00                NaN       91
# 4                NaN                NaN       91
#
# --------------------------------------------------------------------------------
# SEA02.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'NUCLIDE' 'METHOD' '< VALUE_Bq/m³' 'VALUE_Bq/m³' 'ERROR%_m³'
#  'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20318 entries, 0 to 20317
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   KEY            20318 non-null  object
#  1   NUCLIDE        20318 non-null  object
#  2   METHOD         19798 non-null  object
#  3   < VALUE_Bq/m³  500 non-null    object
#  4   VALUE_Bq/m³    20242 non-null  float64
#  5   ERROR%_m³      19610 non-null  float64
#  6   DATE_OF_ENTRY  4418 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 1.1+ MB
# None
#
#             KEY NUCLIDE METHOD < VALUE_Bq/m³  VALUE_Bq/m³  ERROR%_m³  \
# 0  WKRIL2012003   CS137    NaN           NaN          5.3       32.0
# 1  WKRIL2012004   CS137    NaN           NaN         19.9       20.0
# 2  WKRIL2012005   CS137    NaN           NaN         25.5       20.0
# 3  WKRIL2012006   CS137    NaN           NaN         17.0       29.0
# 4  WKRIL2012007   CS137    NaN           NaN         22.2       18.0
#
#        DATE_OF_ENTRY
# 0  08/20/14 00:00:00
# 1  08/20/14 00:00:00
# 2  08/20/14 00:00:00
# 3  08/20/14 00:00:00
# 4  08/20/14 00:00:00
#
# --------------------------------------------------------------------------------
# SEA01.csv
# --------------------------------------------------------------------------------
#
# Columns: ['KEY' 'COUNTRY' 'LABORATORY' 'SEQUENCE' 'DATE' 'YEAR' 'MONTH' 'DAY'
#  'STATION' 'LATITUDE (ddmmmm)' 'LATITUDE (dddddd)' 'LONGITUDE (ddmmmm)'
#  'LONGITUDE (dddddd)' 'TDEPTH' 'SDEPTH' 'SALIN' 'TTEMP' 'FILT'
#  'MORS_SUBBASIN' 'HELCOM_SUBBASIN' 'DATE_OF_ENTRY']
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9111 entries, 0 to 9110
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   KEY                 9111 non-null   object
#  1   COUNTRY             9111 non-null   int64
#  2   LABORATORY          9111 non-null   object
#  3   SEQUENCE            9111 non-null   int64
#  4   DATE                8893 non-null   object
#  5   YEAR                9111 non-null   int64
#  6   MONTH               9111 non-null   int64
#  7   DAY                 9109 non-null   float64
#  8   STATION             9099 non-null   object
#  9   LATITUDE (ddmmmm)   9111 non-null   float64
#  10  LATITUDE (dddddd)   9111 non-null   float64
#  11  LONGITUDE (ddmmmm)  9111 non-null   float64
#  12  LONGITUDE (dddddd)  9111 non-null   float64
#  13  TDEPTH              9037 non-null   float64
#  14  SDEPTH              9110 non-null   float64
#  15  SALIN               9001 non-null   float64
#  16  TTEMP               5143 non-null   float64
#  17  FILT                8961 non-null   object
#  18  MORS_SUBBASIN       9111 non-null   int64
#  19  HELCOM_SUBBASIN     9111 non-null   int64
#  20  DATE_OF_ENTRY       2472 non-null   object
# dtypes: float64(9), int64(6), object(6)
# memory usage: 1.5+ MB
# None
#
#             KEY  COUNTRY LABORATORY  SEQUENCE               DATE  YEAR  MONTH  \
# 0  WCLOR1984001       67       CLOR   1984001  06/13/84 00:00:00  1984      6
# 1  WCLOR1984002       67       CLOR   1984002  06/13/84 00:00:00  1984      6
# 2  WCLOR1984003       67       CLOR   1984003  06/13/84 00:00:00  1984      6
# 3  WCLOR1984004       67       CLOR   1984004  06/13/84 00:00:00  1984      6
# 4  WCLOR1984005       67       CLOR   1984005  06/14/84 00:00:00  1984      6
#
#     DAY STATION  LATITUDE (ddmmmm)  ...  LONGITUDE (ddmmmm)  \
# 0  13.0     ZN2              54.23  ...             18.5705
# 1  13.0     ZN2              54.23  ...             18.5705
# 2  13.0    P110              54.30  ...             19.0608
# 3  13.0    P110              54.30  ...             19.0608
# 4  14.0    P116              54.39  ...             19.1800
#
#    LONGITUDE (dddddd)  TDEPTH  SDEPTH  SALIN  TTEMP  FILT MORS_SUBBASIN  \
# 0             18.9508    16.0     0.0    4.6    NaN     N             4
# 1             18.9508    16.0    14.0    7.8    NaN     N             4
# 2             19.1013    70.0     0.0    6.9    NaN     N             4
# 3             19.1013    70.0    68.0    8.4    NaN     N             4
# 4             19.3000    87.0     0.0    8.0    NaN     N             4
#
#    HELCOM_SUBBASIN  DATE_OF_ENTRY
# 0                4            NaN
# 1                4            NaN
# 2                4            NaN
# 3                4            NaN
# 4                4            NaN
#
# [5 rows x 21 columns]

# %%
sed01 = pd.read_csv(Path(src_dir)/'SED01.csv')
sed02 = pd.read_csv(Path(src_dir)/'SED02.csv')

# %%
# station/location date of sample (KEY is unique)
sed01
# Out:
#                 KEY  COUNTRY LABORATORY  SEQUENCE               DATE  YEAR  \
# 0      SCLOR1984001     67.0       CLOR   1984001  06/03/84 00:00:00  1984
# 1      SCLOR1984002     67.0       CLOR   1984002  06/03/84 00:00:00  1984
# 2      SCLOR1984003     67.0       CLOR   1984003  06/03/84 00:00:00  1984
# 3      SCLOR1984004     67.0       CLOR   1984004  06/03/84 00:00:00  1984
# 4      SCLOR1984005     67.0       CLOR   1984005  06/03/84 00:00:00  1984
# ...             ...      ...        ...       ...                ...   ...
# 12747  SCLOR2018068     67.0       CLOR   2018068  06/06/18 00:00:00  2018
# 12748  SCLOR2018069     67.0       CLOR   2018069  06/06/18 00:00:00  2018
# 12749  SCLOR2018070     67.0       CLOR   2018070  06/06/18 00:00:00  2018
# 12750  SCLOR2018071     67.0       CLOR   2018071  06/06/18 00:00:00  2018
# 12751  SCLOR2018072     67.0       CLOR   2018072  06/06/18 00:00:00  2018
#
#        MONTH  DAY STATION  LATITUDE (ddmmmm)  ...  LOWSLI     AREA  SEDI OXIC  \
# 0          6  3.0     B12             54.200  ...     5.0  0.00500 -99.0  NaN
# 1          6  3.0     B12             54.200  ...    10.0  0.00500 -99.0  NaN
# 2          6  3.0     B12             54.200  ...    15.0  0.00500 -99.0  NaN
# 3          6  3.0     B12             54.200  ...    20.0  0.00500 -99.0  NaN
# 4          6  3.0     B12             54.200  ...    25.0  0.00500 -99.0  NaN
# ...      ...  ...     ...                ...  ...     ...      ...   ...  ...
# 12747      6  6.0     P39             54.445  ...    11.0  0.01178  34.0    A
# 12748      6  6.0     P39             54.445  ...    13.0  0.01178  34.0    A
# 12749      6  6.0     P39             54.445  ...    15.0  0.01178  34.0    A
# 12750      6  6.0     P39             54.445  ...    17.0  0.01178  34.0    A
# 12751      6  6.0     P39             54.445  ...    19.0  0.01178  34.0    A
#
#         DW%  LOI%  MORS_SUBBASIN  HELCOM_SUBBASIN  SUM_LINK      DATE_OF_ENTRY
# 0       NaN   NaN              2                6         a                NaN
# 1       NaN   NaN              2                6         a                NaN
# 2       NaN   NaN              2                6         a                NaN
# 3       NaN   NaN              2                6         a                NaN
# 4       NaN   NaN              2                6         a                NaN
# ...     ...   ...            ...              ...       ...                ...
# 12747  23.1   NaN              6                6       NaN  03/30/20 00:00:00
# 12748  24.2   NaN              6                6       NaN  03/30/20 00:00:00
# 12749  25.3   NaN              6                6       NaN  03/30/20 00:00:00
# 12750  25.3   NaN              6                6       NaN  03/30/20 00:00:00
# 12751  25.4   NaN              6                6       NaN  03/30/20 00:00:00
#
# [12752 rows x 26 columns]

# %%
sed01['LATITUDE (ddmmmm)']
# Out:
# 0        54.200
# 1        54.200
# 2        54.200
# 3        54.200
# 4        54.200
#           ...
# 12747    54.445
# 12748    54.445
# 12749    54.445
# 12750    54.445
# 12751    54.445
# Name: LATITUDE (ddmmmm), Length: 12752, dtype: float64

# %%
sed01['LATITUDE (dddddd)']
# Out:
# 0        54.3333
# 1        54.3333
# 2        54.3333
# 3        54.3333
# 4        54.3333
#           ...
# 12747    54.7417
# 12748    54.7417
# 12749    54.7417
# 12750    54.7417
# 12751    54.7417
# Name: LATITUDE (dddddd), Length: 12752, dtype: float64

# %%
sed01.LABORATORY.unique()
# Out:
# array(['CLOR', 'DHIG', 'EBRS', 'ERPC', 'KRIL', 'LEPA', 'LVDC', 'LREB',
#        'LVEA', 'NCRS', 'RISO', 'SAAS', 'SSSI', 'SSSM', 'STUK'],
#       dtype=object)

# %%
# 
len(sed01.KEY.unique())
# Out:
# 12752

# %%
len(sed02.KEY.unique())
# Out:
# 12730

# %%
sed02[sed02.duplicated(subset='KEY')]
# Out:
#                 KEY NUCLIDE  METHOD < VALUE_Bq/kg  VALUE_Bq/kg  ERROR%_kg  \
# 186    SKRIL2012048   CS137     NaN           NaN         3.00       33.0
# 187    SKRIL2012049   CS137     NaN             <         1.00        NaN
# 188    SKRIL2012050   CS137     NaN           NaN       270.00       21.0
# 189    SKRIL2012051   CS137     NaN           NaN       420.00       20.0
# 190    SKRIL2012052   CS137     NaN           NaN       440.00       20.0
# ...             ...     ...     ...           ...          ...        ...
# 37342  SSTUK2016044   CS137  STUK01           NaN         1.20       12.0
# 37343  SSTUK2016045   CS137  STUK01           NaN         0.79       20.0
# 37344  SSTUK2016050   CS137  STUK01           NaN       512.00       11.0
# 37345  SSTUK2016051   CS137  STUK01           NaN       527.00        6.3
# 37346  SSTUK2016052   CS137  STUK01           NaN       684.00        5.0
#
#       < VALUE_Bq/m²  VALUE_Bq/m²  ERROR%_m²      DATE_OF_ENTRY
# 186             NaN          NaN        NaN  08/20/14 00:00:00
# 187             NaN          NaN        NaN  08/20/14 00:00:00
# 188             NaN          NaN        NaN  08/20/14 00:00:00
# 189             NaN          NaN        NaN  08/20/14 00:00:00
# 190             NaN          NaN        NaN  08/20/14 00:00:00
# ...             ...          ...        ...                ...
# 37342           NaN     8.916443       15.0                NaN
# 37343           NaN     5.992930       23.0                NaN
# 37344           NaN  2164.945699       14.0                NaN
# 37345           NaN  2523.279045        9.3                NaN
# 37346           NaN  3929.780107        8.0                NaN
#
# [24617 rows x 10 columns]

# %%
sed02[sed02.KEY == 'SKRIL2012048']
# Out:
#               KEY NUCLIDE METHOD < VALUE_Bq/kg  VALUE_Bq/kg  ERROR%_kg  \
# 0    SKRIL2012048   RA226    NaN           NaN         35.0       26.0
# 186  SKRIL2012048   CS137    NaN           NaN          3.0       33.0
# 562  SKRIL2012048   RA228    NaN           NaN         60.0       20.0
# 825  SKRIL2012048     K40    NaN           NaN        980.0       20.0
#
#     < VALUE_Bq/m²  VALUE_Bq/m²  ERROR%_m²      DATE_OF_ENTRY
# 0             NaN          NaN        NaN  08/20/14 00:00:00
# 186           NaN          NaN        NaN  08/20/14 00:00:00
# 562           NaN          NaN        NaN  08/20/14 00:00:00
# 825           NaN          NaN        NaN  08/20/14 00:00:00

# %% [markdown]
# ## Load sediments

# %%
sediments = pd.merge(pd.read_csv(Path(src_dir)/'SED02.csv'), # measurements
                     pd.read_csv(Path(src_dir)/'SED01.csv'), # sample
                     on='KEY', how='left')

# %%
sediments.head()
# Out:
#             KEY NUCLIDE METHOD < VALUE_Bq/kg  VALUE_Bq/kg  ERROR%_kg  \
# 0  SKRIL2012048   RA226    NaN           NaN         35.0       26.0
# 1  SKRIL2012049   RA226    NaN           NaN         36.0       22.0
# 2  SKRIL2012050   RA226    NaN           NaN         38.0       24.0
# 3  SKRIL2012051   RA226    NaN           NaN         36.0       25.0
# 4  SKRIL2012052   RA226    NaN           NaN         30.0       23.0
#
#   < VALUE_Bq/m²  VALUE_Bq/m²  ERROR%_m²    DATE_OF_ENTRY_x  ...  LOWSLI  \
# 0           NaN          NaN        NaN  08/20/14 00:00:00  ...    20.0
# 1           NaN          NaN        NaN  08/20/14 00:00:00  ...    27.0
# 2           NaN          NaN        NaN  08/20/14 00:00:00  ...     2.0
# 3           NaN          NaN        NaN  08/20/14 00:00:00  ...     4.0
# 4           NaN          NaN        NaN  08/20/14 00:00:00  ...     6.0
#
#     AREA  SEDI OXIC  DW%  LOI%  MORS_SUBBASIN HELCOM_SUBBASIN  SUM_LINK  \
# 0  0.006   NaN  NaN  NaN   NaN           11.0            11.0       NaN
# 1  0.006   NaN  NaN  NaN   NaN           11.0            11.0       NaN
# 2  0.006   NaN  NaN  NaN   NaN           11.0            11.0       NaN
# 3  0.006   NaN  NaN  NaN   NaN           11.0            11.0       NaN
# 4  0.006   NaN  NaN  NaN   NaN           11.0            11.0       NaN
#
#      DATE_OF_ENTRY_y
# 0  08/20/14 00:00:00
# 1  08/20/14 00:00:00
# 2  08/20/14 00:00:00
# 3  08/20/14 00:00:00
# 4  08/20/14 00:00:00
#
# [5 rows x 35 columns]

# %%
sediments.columns
# Out:
# Index(['KEY', 'NUCLIDE', 'METHOD', '< VALUE_Bq/kg', 'VALUE_Bq/kg', 'ERROR%_kg',
#        '< VALUE_Bq/m²', 'VALUE_Bq/m²', 'ERROR%_m²', 'DATE_OF_ENTRY_x',
#        'COUNTRY', 'LABORATORY', 'SEQUENCE', 'DATE', 'YEAR', 'MONTH', 'DAY',
#        'STATION', 'LATITUDE (ddmmmm)', 'LATITUDE (dddddd)',
#        'LONGITUDE (ddmmmm)', 'LONGITUDE (dddddd)', 'DEVICE', 'TDEPTH',
#        'UPPSLI', 'LOWSLI', 'AREA', 'SEDI', 'OXIC', 'DW%', 'LOI%',
#        'MORS_SUBBASIN', 'HELCOM_SUBBASIN', 'SUM_LINK', 'DATE_OF_ENTRY_y'],
#       dtype='object')

# %% [markdown]
# ### Select cols of interest

# %%
cols = ['NUCLIDE', 'VALUE_Bq/kg', 'ERROR%_kg', 'DATE',
        'TDEPTH', 'LATITUDE (dddddd)', 'LONGITUDE (dddddd)']

# %%
sediments = sediments[cols]; sediments
# Out:
#       NUCLIDE  VALUE_Bq/kg  ERROR%_kg               DATE  TDEPTH  \
# 0       RA226        35.00       26.0  06/17/12 00:00:00    71.0
# 1       RA226        36.00       22.0  06/17/12 00:00:00    71.0
# 2       RA226        38.00       24.0  08/10/12 00:00:00    23.0
# 3       RA226        36.00       25.0  08/10/12 00:00:00    23.0
# 4       RA226        30.00       23.0  08/10/12 00:00:00    23.0
# ...       ...          ...        ...                ...     ...
# 37342   CS137         1.20       12.0  06/09/16 00:00:00   171.0
# 37343   CS137         0.79       20.0  06/09/16 00:00:00   171.0
# 37344   CS137       512.00       11.0  05/29/16 00:00:00   131.0
# 37345   CS137       527.00        6.3  05/29/16 00:00:00   131.0
# 37346   CS137       684.00        5.0  05/29/16 00:00:00   131.0
#
#        LATITUDE (dddddd)  LONGITUDE (dddddd)
# 0                59.6667             24.0000
# 1                59.6667             24.0000
# 2                59.8600             28.8433
# 3                59.8600             28.8433
# 4                59.8600             28.8433
# ...                  ...                 ...
# 37342            59.0360             21.0830
# 37343            59.0360             21.0830
# 37344            61.0667             19.7297
# 37345            61.0667             19.7297
# 37346            61.0667             19.7297
#
# [37347 rows x 7 columns]

# %% [markdown]
# ### Parse time

# %%
pd.to_datetime(sediments.DATE, infer_datetime_format=True)
# Out:
# 0       2012-06-17
# 1       2012-06-17
# 2       2012-08-10
# 3       2012-08-10
# 4       2012-08-10
#            ...
# 37342   2016-06-09
# 37343   2016-06-09
# 37344   2016-05-29
# 37345   2016-05-29
# 37346   2016-05-29
# Name: DATE, Length: 37347, dtype: datetime64[ns]

# %%
sediments['time'] = pd.to_datetime(sediments.DATE, infer_datetime_format=True)

# %%
sediments
# Out:
#       NUCLIDE  VALUE_Bq/kg  ERROR%_kg               DATE  TDEPTH  \
# 0       RA226        35.00       26.0  06/17/12 00:00:00    71.0
# 1       RA226        36.00       22.0  06/17/12 00:00:00    71.0
# 2       RA226        38.00       24.0  08/10/12 00:00:00    23.0
# 3       RA226        36.00       25.0  08/10/12 00:00:00    23.0
# 4       RA226        30.00       23.0  08/10/12 00:00:00    23.0
# ...       ...          ...        ...                ...     ...
# 37342   CS137         1.20       12.0  06/09/16 00:00:00   171.0
# 37343   CS137         0.79       20.0  06/09/16 00:00:00   171.0
# 37344   CS137       512.00       11.0  05/29/16 00:00:00   131.0
# 37345   CS137       527.00        6.3  05/29/16 00:00:00   131.0
# 37346   CS137       684.00        5.0  05/29/16 00:00:00   131.0
#
#        LATITUDE (dddddd)  LONGITUDE (dddddd)       time
# 0                59.6667             24.0000 2012-06-17
# 1                59.6667             24.0000 2012-06-17
# 2                59.8600             28.8433 2012-08-10
# 3                59.8600             28.8433 2012-08-10
# 4                59.8600             28.8433 2012-08-10
# ...                  ...                 ...        ...
# 37342            59.0360             21.0830 2016-06-09
# 37343            59.0360             21.0830 2016-06-09
# 37344            61.0667             19.7297 2016-05-29
# 37345            61.0667             19.7297 2016-05-29
# 37346            61.0667             19.7297 2016-05-29
#
# [37347 rows x 8 columns]

# %%
sediments.drop(columns=['DATE'], inplace=True)

# %% [markdown]
# ### Clean radionuclide types name

# %%
'240Pu/239Pu'
# Out:
# '240Pu/239Pu'

# %%
pd.DataFrame({'240Pu/239Pu': [1,2,3], '240Pu/239Pu_err': [1,2,3],
              '239,240Pu III,IV': [11, 12, 13], '239,240Pu III,IV_err': [11, 12, 13]})
# Out:
#    240Pu/239Pu  240Pu/239Pu_err  239,240Pu III,IV  239,240Pu III,IV_err
# 0            1                1                11                    11
# 1            2                2                12                    12
# 2            3                3                13                    13

# %%
sediments.NUCLIDE.unique()
# Out:
# array(['RA226', 'CS137', 'RA228', 'K40', 'SR90', 'CS134137', 'CS134',
#        'PU239240', 'PU238', 'CO60', 'RU103', 'RU106', 'SB125', 'AG110M',
#        'CE144', 'AM241', 'BE7', 'TH228', 'PB210', 'CO58', 'MN54', 'ZR95',
#        'BA140', 'PO210', 'RA224', 'NB95', 'PU238240', 'PU241', 'PU239',
#        'EU155', 'IR192', 'Cs137', 'TH232', 'Pu239240', 'CD109', 'SB124',
#        'ZN65', 'TH234', 'Pu238', 'Ra226', 'Sr90', 'TL208', 'PB212',
#        'PB214', 'BI214', 'AC228', 'RA223', 'U235', 'BI212', 'CS137 '],
#       dtype=object)

# %%
# 1. to lower case
sediments.NUCLIDE = sediments.NUCLIDE.str.lower()

# %%
sediments.NUCLIDE.unique()
# Out:
# array(['ra226', 'cs137', 'ra228', 'k40', 'sr90', 'cs134137', 'cs134',
#        'pu239240', 'pu238', 'co60', 'ru103', 'ru106', 'sb125', 'ag110m',
#        'ce144', 'am241', 'be7', 'th228', 'pb210', 'co58', 'mn54', 'zr95',
#        'ba140', 'po210', 'ra224', 'nb95', 'pu238240', 'pu241', 'pu239',
#        'eu155', 'ir192', 'th232', 'cd109', 'sb124', 'zn65', 'th234',
#        'tl208', 'pb212', 'pb214', 'bi214', 'ac228', 'ra223', 'u235',
#        'bi212', 'cs137 '], dtype=object)

# %%
# 2. strip (it appears that 'cs137' is also written as 'cs137 '
sediments.NUCLIDE = sediments.NUCLIDE.str.strip()

# %%
sediments.NUCLIDE.unique()
# Out:
# array(['ra226', 'cs137', 'ra228', 'k40', 'sr90', 'cs134137', 'cs134',
#        'pu239240', 'pu238', 'co60', 'ru103', 'ru106', 'sb125', 'ag110m',
#        'ce144', 'am241', 'be7', 'th228', 'pb210', 'co58', 'mn54', 'zr95',
#        'ba140', 'po210', 'ra224', 'nb95', 'pu238240', 'pu241', 'pu239',
#        'eu155', 'ir192', 'th232', 'cd109', 'sb124', 'zn65', 'th234',
#        'tl208', 'pb212', 'pb214', 'bi214', 'ac228', 'ra223', 'u235',
#        'bi212'], dtype=object)

# %%
# 3. normalizing radionuclide aggregates (ration, total) - renaming to be confirmed
sediments = sediments.replace({'cs134137': 'cs134_137_tot', 
                               'pu238240': 'pu238_240_ratio',
                               'pu239240': 'pu239_240_ratio'})

# %%
sediments.NUCLIDE.unique()
# Out:
# array(['ra226', 'cs137', 'ra228', 'k40', 'sr90', 'cs134_137_tot', 'cs134',
#        'pu239_240_ratio', 'pu238', 'co60', 'ru103', 'ru106', 'sb125',
#        'ag110m', 'ce144', 'am241', 'be7', 'th228', 'pb210', 'co58',
#        'mn54', 'zr95', 'ba140', 'po210', 'ra224', 'nb95',
#        'pu238_240_ratio', 'pu241', 'pu239', 'eu155', 'ir192', 'th232',
#        'cd109', 'sb124', 'zn65', 'th234', 'tl208', 'pb212', 'pb214',
#        'bi214', 'ac228', 'ra223', 'u235', 'bi212'], dtype=object)

# %% [markdown]
# ### Columns renaming

# %%
rules = {
    'NUCLIDE': 'nuclide',
    'VALUE_Bq/kg': 'value',
    'ERROR%_kg': 'err',
    'TDEPTH': 'depth',
    'LATITUDE (dddddd)':'latitude',
    'LONGITUDE (dddddd)':'longitude'}
    
sediments.rename(columns=rules, inplace=True)

# %%
sediments
# Out:
#       nuclide   value   err  depth  latitude  longitude       time
# 0       ra226   35.00  26.0   71.0   59.6667    24.0000 2012-06-17
# 1       ra226   36.00  22.0   71.0   59.6667    24.0000 2012-06-17
# 2       ra226   38.00  24.0   23.0   59.8600    28.8433 2012-08-10
# 3       ra226   36.00  25.0   23.0   59.8600    28.8433 2012-08-10
# 4       ra226   30.00  23.0   23.0   59.8600    28.8433 2012-08-10
# ...       ...     ...   ...    ...       ...        ...        ...
# 37342   cs137    1.20  12.0  171.0   59.0360    21.0830 2016-06-09
# 37343   cs137    0.79  20.0  171.0   59.0360    21.0830 2016-06-09
# 37344   cs137  512.00  11.0  131.0   61.0667    19.7297 2016-05-29
# 37345   cs137  527.00   6.3  131.0   61.0667    19.7297 2016-05-29
# 37346   cs137  684.00   5.0  131.0   61.0667    19.7297 2016-05-29
#
# [37347 rows x 7 columns]

# %%
sediments = sediments.pivot_table(index=['time', 'latitude', 'longitude', 'depth'], 
                                  columns='nuclide', values=['value', 'err']).reset_index(); sediments
# Out:
#               time latitude longitude  depth   err                         \
# nuclide                                      ac228 ag110m am241 ba140 be7
# 0       1984-06-03  54.3333   14.4183   63.0   NaN    NaN   NaN   NaN NaN
# 1       1984-06-03  55.2167   17.0667   92.0   NaN    NaN   NaN   NaN NaN
# 2       1984-06-03  55.2500   15.9833   91.0   NaN    NaN   NaN   NaN NaN
# 3       1984-06-03  55.2500   19.9833   91.0   NaN    NaN   NaN   NaN NaN
# 4       1984-06-05  54.8333   19.3333  109.0   NaN    NaN   NaN   NaN NaN
# ...            ...      ...       ...    ...   ...    ...   ...   ...  ..
# 1727    2018-09-17  61.0833   19.5797  125.0   NaN    NaN   NaN   NaN NaN
# 1728    2018-10-10  55.7272   12.8437   20.0   NaN    NaN   NaN   NaN NaN
# 1729    2018-10-18  55.6333   20.8000   45.0   NaN    NaN   NaN   NaN NaN
# 1730    2018-10-18  55.5583   21.0783   13.0   NaN    NaN   NaN   NaN NaN
# 1731    2018-11-05  55.3050   21.0266    4.0   NaN    NaN   NaN   NaN NaN
#
#                ... value
# nuclide bi212  ... sb124 sb125  sr90 th228 th232 th234 tl208 u235 zn65 zr95
# 0         NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1         NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2         NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3         NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 4         NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# ...       ...  ...   ...   ...   ...   ...   ...   ...   ...  ...  ...  ...
# 1727      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1728      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1729      NaN  ...   NaN   NaN  9.17   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1730      NaN  ...   NaN   NaN  3.42   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1731      NaN  ...   NaN   NaN  3.58   NaN   NaN   NaN   NaN  NaN  NaN  NaN
#
# [1732 rows x 90 columns]

# %%
def rename_cols(cols):
    new_cols = []
    for outer, inner in cols:
        if not inner:
            new_cols.append(outer)
        else:
            if outer == 'err':
                new_cols.append(inner + '_' + outer)
            if outer == 'value':
                new_cols.append(inner)
    return new_cols

# %%
sediments.columns = rename_cols(sediments.columns)

# %%
sediments
# Out:
#            time  latitude  longitude  depth  ac228_err  ag110m_err  am241_err  \
# 0    1984-06-03   54.3333    14.4183   63.0        NaN         NaN        NaN
# 1    1984-06-03   55.2167    17.0667   92.0        NaN         NaN        NaN
# 2    1984-06-03   55.2500    15.9833   91.0        NaN         NaN        NaN
# 3    1984-06-03   55.2500    19.9833   91.0        NaN         NaN        NaN
# 4    1984-06-05   54.8333    19.3333  109.0        NaN         NaN        NaN
# ...         ...       ...        ...    ...        ...         ...        ...
# 1727 2018-09-17   61.0833    19.5797  125.0        NaN         NaN        NaN
# 1728 2018-10-10   55.7272    12.8437   20.0        NaN         NaN        NaN
# 1729 2018-10-18   55.6333    20.8000   45.0        NaN         NaN        NaN
# 1730 2018-10-18   55.5583    21.0783   13.0        NaN         NaN        NaN
# 1731 2018-11-05   55.3050    21.0266    4.0        NaN         NaN        NaN
#
#       ba140_err  be7_err  bi212_err  ...  sb124  sb125  sr90  th228  th232  \
# 0           NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 1           NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 2           NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 3           NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 4           NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# ...         ...      ...        ...  ...    ...    ...   ...    ...    ...
# 1727        NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 1728        NaN      NaN        NaN  ...    NaN    NaN   NaN    NaN    NaN
# 1729        NaN      NaN        NaN  ...    NaN    NaN  9.17    NaN    NaN
# 1730        NaN      NaN        NaN  ...    NaN    NaN  3.42    NaN    NaN
# 1731        NaN      NaN        NaN  ...    NaN    NaN  3.58    NaN    NaN
#
#       th234  tl208  u235  zn65  zr95
# 0       NaN    NaN   NaN   NaN   NaN
# 1       NaN    NaN   NaN   NaN   NaN
# 2       NaN    NaN   NaN   NaN   NaN
# 3       NaN    NaN   NaN   NaN   NaN
# 4       NaN    NaN   NaN   NaN   NaN
# ...     ...    ...   ...   ...   ...
# 1727    NaN    NaN   NaN   NaN   NaN
# 1728    NaN    NaN   NaN   NaN   NaN
# 1729    NaN    NaN   NaN   NaN   NaN
# 1730    NaN    NaN   NaN   NaN   NaN
# 1731    NaN    NaN   NaN   NaN   NaN
#
# [1732 rows x 90 columns]

# %% [markdown]
# ### Renaming index (dim) & encoding time

# %%
sediments.index.name = 'sample'

# %%
# Encoding time as seconds since ...
format_time = lambda x: date2num(x, units="seconds since 1970-01-01 00:00:00.0")
sediments['time'] = sediments['time'].apply(format_time)

# %%
sediments
# Out:
#               time  latitude  longitude  depth  ac228_err  ag110m_err  \
# sample
# 0        455068800   54.3333    14.4183   63.0        NaN         NaN
# 1        455068800   55.2167    17.0667   92.0        NaN         NaN
# 2        455068800   55.2500    15.9833   91.0        NaN         NaN
# 3        455068800   55.2500    19.9833   91.0        NaN         NaN
# 4        455241600   54.8333    19.3333  109.0        NaN         NaN
# ...            ...       ...        ...    ...        ...         ...
# 1727    1537142400   61.0833    19.5797  125.0        NaN         NaN
# 1728    1539129600   55.7272    12.8437   20.0        NaN         NaN
# 1729    1539820800   55.6333    20.8000   45.0        NaN         NaN
# 1730    1539820800   55.5583    21.0783   13.0        NaN         NaN
# 1731    1541376000   55.3050    21.0266    4.0        NaN         NaN
#
#         am241_err  ba140_err  be7_err  bi212_err  ...  sb124  sb125  sr90  \
# sample                                            ...
# 0             NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 1             NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 2             NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 3             NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 4             NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# ...           ...        ...      ...        ...  ...    ...    ...   ...
# 1727          NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 1728          NaN        NaN      NaN        NaN  ...    NaN    NaN   NaN
# 1729          NaN        NaN      NaN        NaN  ...    NaN    NaN  9.17
# 1730          NaN        NaN      NaN        NaN  ...    NaN    NaN  3.42
# 1731          NaN        NaN      NaN        NaN  ...    NaN    NaN  3.58
#
#         th228  th232  th234  tl208  u235  zn65  zr95
# sample
# 0         NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1         NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 2         NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 3         NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 4         NaN    NaN    NaN    NaN   NaN   NaN   NaN
# ...       ...    ...    ...    ...   ...   ...   ...
# 1727      NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1728      NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1729      NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1730      NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1731      NaN    NaN    NaN    NaN   NaN   NaN   NaN
#
# [1732 rows x 90 columns]

# %% [markdown]
# ### As NetCDF3 (classic)

# %%
with Dataset('maris-template-v3.nc') as src, Dataset('output/helcom-sed-v3.nc', 'w', format='NETCDF3_CLASSIC') as dst:
    # copy global attributes all at once via dictionary
    dst.setncatts(src.__dict__)
    
    # copy dimensions
    for name, dimension in src.dimensions.items():
        dst.createDimension(
            name, (len(dimension) if not dimension.isunlimited() else None))
    
    # copy all variables of interest and fill them
    for name_var_src, var_src in src.variables.items():
        if name_var_src in sediments.reset_index().columns:
            x = dst.createVariable(name_var_src, var_src.datatype, var_src.dimensions,
                                   compression='zlib', complevel=9)
            # fill variables
            dst[name_var_src][:] = sediments.reset_index()[name_var_src].values
            # copy variable attributes all at once via dictionary
            dst[name_var_src].setncatts(src[name_var_src].__dict__)

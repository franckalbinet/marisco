# %% [markdown]
# # MARIS to WoRMS
# Reconciling MARIS species with WoRMS ones

# %%
import pandas as pd
from pathlib import Path
from fastcore.xtras import save_pickle, load_pickle
from marisco.utils import match_worms
from tqdm import tqdm

# %% [markdown]
# ## Load MARIS Excel lookup table

# %%
df_species = pd.read_excel('../files/lut/dbo_species.xlsx')

# %%
df_species.head()
# Out:
#    species_id                             species code  biogroup  biogroup_id  \
# 0           0                       Not available    0       NaN            0
# 1           1                 Aristeus antennatus   AA       NaN            2
# 2           2                        Apostichopus   xx       NaN            3
# 3           3  Saccharina japonica var. religiosa   xx       NaN           11
# 4           4                  Siganus fuscescens   xx       NaN            4
#
#         organism  codorg                           Taxonname      Taxonrank  \
# 0  NOT AVAILABLE       0                     (Not available)  Not available
# 1       DECAPODA  CRUDEC                 Aristeus antennatus        species
# 2             xx      xx                        Apostichopus          genus
# 3             xx      xx  Saccharina japonica var. religiosa        variety
# 4             xx      xx                  Siganus fuscescens        species
#
#    Commonname        TaxonDB      TaxonDBID  \
# 0         NaN  Not available  Not available
# 1         NaN       Wikidata        Q500678
# 2         NaN       Wikidata       Q4780592
# 3         NaN       Wikidata      Q68486806
# 4         NaN       Wikidata        Q867673
#
#                                 TaxonDBURL TaxonDB2  TaxonDBID2  \
# 0                            Not available      NaN         NaN
# 1    https://www.wikidata.org/wiki/Q500678    WoRMS    107083.0
# 2   https://www.wikidata.org/wiki/Q4780592      NaN         NaN
# 3  https://www.wikidata.org/wiki/Q68486806      NaN         NaN
# 4    https://www.wikidata.org/wiki/Q867673      NaN         NaN
#
#                                          TaxonDBURL2  \
# 0                                                NaN
# 1  http://www.marinespecies.org/aphia.php?p=taxde...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  SQL
# 0                                                NaN
# 1  if ((select species_id from species where taxo...
# 2  if ((select species_id from species where taxo...
# 3  if ((select species_id from species where taxo...
# 4  if ((select species_id from species where taxo...

# %% [markdown]
# ## Query WoRMS db

# %%
maris2worms = {}

for species in tqdm(df_species['species'].values):
    maris2worms[species] = match_worms(species)

del maris2worms['Not available']
# Out:
# 100%|██████████| 1611/1611 [1:44:11<00:00,  3.88s/it]

# %%
maris2worms['Siganus fuscescens']
# Out:
# [[{'AphiaID': 273912,
#    'url': 'https://www.marinespecies.org/aphia.php?p=taxdetails&id=273912',
#    'scientificname': 'Siganus fuscescens',
#    'authority': '(Houttuyn, 1782)',
#    'status': 'accepted',
#    'unacceptreason': None,
#    'taxonRankID': 220,
#    'rank': 'Species',
#    'valid_AphiaID': 273912,
#    'valid_name': 'Siganus fuscescens',
#    'valid_authority': '(Houttuyn, 1782)',
#    'parentNameUsageID': 126071,
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'class': 'Teleostei',
#    'order': 'Acanthuriformes',
#    'family': 'Siganidae',
#    'genus': 'Siganus',
#    'citation': 'Froese, R. and D. Pauly. Editors. (2023). FishBase. Siganus fuscescens (Houttuyn, 1782). Accessed through: World Register of Marine Species at: https://www.marinespecies.org/aphia.php?p=taxdetails&id=273912 on 2023-06-16',
#    'lsid': 'urn:lsid:marinespecies.org:taxname:273912',
#    'isMarine': 1,
#    'isBrackish': 1,
#    'isFreshwater': 0,
#    'isTerrestrial': 0,
#    'isExtinct': None,
#    'match_type': 'exact',
#    'modified': '2008-01-15T17:27:08.177Z'}]]

# %% [markdown]
# ### Save or load

# %%
fname_dump = Path('../files/dump') / 'maris2worms.pkl'
if maris2worms:
    save_pickle(fname_dump, maris2worms)
else:
    maris2worms = load_pickle(fname_dump)
# Out:
# exist

# %% [markdown]
# ## Summary stats

# %%
results = {'maris_species': [], 'n_matches': [],
           'aphiaid': [], 'status': [], 'worms_species': []}

for k in maris2worms.keys():
    results['maris_species'].append(k)
    # If no match
    if maris2worms[k] == -1:
        results['n_matches'].append(0)
        results['aphiaid'].append(-1)
        results['status'].append(None)
        results['worms_species'].append(None)
    else:
        n_matches = len(maris2worms[k][0])
        attrs = maris2worms[k][0][0]
        results['n_matches'].append(n_matches)
        results['aphiaid'].append(attrs['AphiaID'])
        results['status'].append(attrs['status'])
        results['worms_species'].append(attrs['scientificname'])

# %%
df = pd.DataFrame(results); df.head()
# Out:
#                         maris_species  n_matches  aphiaid    status  \
# 0                 Aristeus antennatus          1   107083  accepted
# 1                        Apostichopus          1   241373  accepted
# 2  Saccharina japonica var. religiosa          1   847544  accepted
# 3                  Siganus fuscescens          1   273912  accepted
# 4                    Alpheus dentipes          1   107475  accepted
#
#                         worms_species
# 0                 Aristeus antennatus
# 1                        Apostichopus
# 2  Saccharina japonica var. religiosa
# 3                  Siganus fuscescens
# 4                    Alpheus dentipes

# %%
df_missing = df[df['n_matches'] == 0]
print(f'# missing: {len(df_missing)}')
df_missing.head(20)
# Out:
# # missing: 34
#                      maris_species  n_matches  aphiaid status worms_species
# 46       Carassius auratus auratus          0       -1   None          None
# 158                        Neuston          0       -1   None          None
# 254                  Pusa sibirica          0       -1   None          None
# 276                    Fish larvae          0       -1   None          None
# 586   Parastichopus nigripunctatus          0       -1   None          None
# 662                 Scomberomorini          0       -1   None          None
# 663                   Channa argus          0       -1   None          None
# 694                    Zooplankton          0       -1   None          None
# 695                  Phytoplankton          0       -1   None          None
# 733                   Marine algae          0       -1   None          None
# 913             Charybdis lucifera          0       -1   None          None
# 942             Charybdis feriatus          0       -1   None          None
# 950       Seriola lalandi dorsalis          0       -1   None          None
# 957           Sartoriana spinigera          0       -1   None          None
# 958         Lamellidens marginalis          0       -1   None          None
# 989              Pomacea bridgesii          0       -1   None          None
# 1017                      Therapon          0       -1   None          None
# 1058                       Seaweed          0       -1   None          None
# 1100   Chrysichthys nigrodigitatus          0       -1   None          None
# 1127          Cladonia rangiferina          0       -1   None          None

# %%
df_multi = df[df['n_matches'] > 1]
print(f'# missing: {len(df_multi)}')
df_multi.head(20)
# Out:
# # missing: 34
#                 maris_species  n_matches  aphiaid      status  \
# 39      Balaenoptera musculus          2   137090    accepted
# 72                  Chrysaora          2   135261    accepted
# 92         Delphinus capensis          3   383815  unaccepted
# 135                Holothuria          2   123456    accepted
# 167   Mesoplodon densirostris          3   137122    accepted
# 241              Polysiphonia          3   143853    accepted
# 245            Gonostomatidae          2   125601    accepted
# 408                     Gadus          2   125732    accepted
# 558       Synagrops japonicus          2   367291    accepted
# 700         Ceramium virgatum          2   178915    accepted
# 734          Scarus rivulatus          2   367210    accepted
# 749            Alectis indica          2   401562    accepted
# 781        Johnius dussumieri          2   367241    accepted
# 859                  Dasyatis          2   105751    accepted
# 891            Pagrus auratus          2   398546    accepted
# 947             Uca annulipes          3   558114  unaccepted
# 1031      Harengula humeralis          2   367197    accepted
# 1064         Solen marginatus          2   141546    accepted
# 1102      Actinauge abyssorum          2   100929    accepted
# 1143             Dosinia alta          2   216569    accepted
#
#                  worms_species
# 39       Balaenoptera musculus
# 72                   Chrysaora
# 92          Delphinus capensis
# 135                 Holothuria
# 167    Mesoplodon densirostris
# 241               Polysiphonia
# 245             Gonostomatidae
# 408                      Gadus
# 558        Synagrops japonicus
# 700          Ceramium virgatum
# 734           Scarus rivulatus
# 749             Alectis indica
# 781         Johnius dussumieri
# 859                   Dasyatis
# 891             Pagrus auratus
# 947   Uca (Austruca) annulipes
# 1031       Harengula humeralis
# 1064          Solen marginatus
# 1102       Actinauge abyssorum
# 1143              Dosinia alta

# %%
df_accepted = df[df['status'] == 'accepted']
print(f'# accepted: {len(df_accepted)}')
df_accepted.head(20)
# Out:
# # accepted: 1409
#                          maris_species  n_matches  aphiaid    status  \
# 0                  Aristeus antennatus          1   107083  accepted
# 1                         Apostichopus          1   241373  accepted
# 2   Saccharina japonica var. religiosa          1   847544  accepted
# 3                   Siganus fuscescens          1   273912  accepted
# 4                     Alpheus dentipes          1   107475  accepted
# 5                 Hexagrammos agrammus          1   279410  accepted
# 6                   Ditrema temminckii          1   280570  accepted
# 7           Parapristipoma trilineatum          1   273480  accepted
# 8                      Scombrops boops          1   220088  accepted
# 9          Pseudopleuronectes schrenki          1   275359  accepted
# 10                Desmarestia ligulata          1   145309  accepted
# 11                 Saccharina japonica          1   377084  accepted
# 12                  Neodilsea yendoana          1   372179  accepted
# 13                    Costaria costata          1   371985  accepted
# 14                  Sargassum yezoense          1   494879  accepted
# 15               Acanthephyra pelagica          1   107581  accepted
# 16             Sargassum ringgoldianum          1   494866  accepted
# 17          Acanthephyra quadrispinosa          1   210438  accepted
# 18                Sargassum thunbergii          1   494874  accepted
# 19                    Sargassum patens          1   494863  accepted
#
#                          worms_species
# 0                  Aristeus antennatus
# 1                         Apostichopus
# 2   Saccharina japonica var. religiosa
# 3                   Siganus fuscescens
# 4                     Alpheus dentipes
# 5                 Hexagrammos agrammus
# 6                   Ditrema temminckii
# 7           Parapristipoma trilineatum
# 8                      Scombrops boops
# 9          Pseudopleuronectes schrenki
# 10                Desmarestia ligulata
# 11                 Saccharina japonica
# 12                  Neodilsea yendoana
# 13                    Costaria costata
# 14                  Sargassum yezoense
# 15               Acanthephyra pelagica
# 16             Sargassum ringgoldianum
# 17          Acanthephyra quadrispinosa
# 18                Sargassum thunbergii
# 19                    Sargassum patens

# %% [markdown]
# ## Excel lut expansion

# %%
import numpy as np

# %%
cols_worms = {k: [] for k in maris2worms['Siganus fuscescens'][0][0].keys()}
cols_all = {'species': []}
cols_all.update(cols_worms)

for k in maris2worms.keys():
    if maris2worms[k] == -1:
        cols_all['species'].append(k)
        for col in cols_worms.keys(): 
            cols_all[col].append(np.nan)
    else:
        for matches in maris2worms[k][0]:
            cols_all['species'].append(k)
            for k_m, v_m in matches.items():
                cols_all[k_m].append(v_m)

# %%
df_expanded = pd.DataFrame(cols_all)
df_expanded.head()
# Out:
#                               species   AphiaID  \
# 0                 Aristeus antennatus  107083.0
# 1                        Apostichopus  241373.0
# 2  Saccharina japonica var. religiosa  847544.0
# 3                  Siganus fuscescens  273912.0
# 4                    Alpheus dentipes  107475.0
#
#                                                  url  \
# 0  https://www.marinespecies.org/aphia.php?p=taxd...
# 1  https://www.marinespecies.org/aphia.php?p=taxd...
# 2  https://www.marinespecies.org/aphia.php?p=taxd...
# 3  https://www.marinespecies.org/aphia.php?p=taxd...
# 4  https://www.marinespecies.org/aphia.php?p=taxd...
#
#                        scientificname  \
# 0                 Aristeus antennatus
# 1                        Apostichopus
# 2  Saccharina japonica var. religiosa
# 3                  Siganus fuscescens
# 4                    Alpheus dentipes
#
#                                            authority    status unacceptreason  \
# 0                                      (Risso, 1816)  accepted           None
# 1                                         Liao, 1980  accepted           None
# 2  (Miyabe) N.Yotsukura, S.Kawashima, T.Kawai, T....  accepted           None
# 3                                   (Houttuyn, 1782)  accepted           None
# 4                                       Guérin, 1832  accepted           None
#
#    taxonRankID     rank  valid_AphiaID  ...         genus  \
# 0        220.0  Species       107083.0  ...      Aristeus
# 1        180.0    Genus       241373.0  ...  Apostichopus
# 2        240.0  Variety       847544.0  ...    Saccharina
# 3        220.0  Species       273912.0  ...       Siganus
# 4        220.0  Species       107475.0  ...       Alpheus
#
#                                             citation  \
# 0  DecaNet eds. (2023). DecaNet. Aristeus antenna...
# 1  WoRMS (2023). Apostichopus Liao, 1980. Accesse...
# 2  Guiry, M.D. & Guiry, G.M. (2023). AlgaeBase. W...
# 3  Froese, R. and D. Pauly. Editors. (2023). Fish...
# 4  DecaNet eds. (2023). DecaNet. Alpheus dentipes...
#
#                                         lsid isMarine isBrackish isFreshwater  \
# 0  urn:lsid:marinespecies.org:taxname:107083      1.0        0.0          0.0
# 1  urn:lsid:marinespecies.org:taxname:241373      1.0        NaN          0.0
# 2  urn:lsid:marinespecies.org:taxname:847544      1.0        NaN          NaN
# 3  urn:lsid:marinespecies.org:taxname:273912      1.0        1.0          0.0
# 4  urn:lsid:marinespecies.org:taxname:107475      1.0        0.0          0.0
#
#   isTerrestrial isExtinct match_type                  modified
# 0           0.0       0.0      exact  2022-08-24T09:48:14.813Z
# 1           0.0       NaN      exact  2013-06-10T05:18:23.057Z
# 2           NaN       NaN      exact  2015-06-26T12:00:51.270Z
# 3           0.0       NaN      exact  2008-01-15T17:27:08.177Z
# 4           0.0       0.0      exact  2022-05-13T08:15:22.193Z
#
# [5 rows x 28 columns]

# %%
col_types = {c: pd.Int64Dtype() 
             for c in ['AphiaID', 'taxonRankID', 'valid_AphiaID', 
                       'parentNameUsageID','isMarine', 'isBrackish',
                       'isFreshwater', 'isTerrestrial', 'isExtinct']}
df_expanded = df_expanded.astype(col_types)

# %%
df_expanded[df_expanded.duplicated(subset='species')].head()
# Out:
#                    species  AphiaID  \
# 40   Balaenoptera musculus   380449
# 74               Chrysaora  1379174
# 95      Delphinus capensis   137093
# 96      Delphinus capensis   383816
# 140             Holothuria  1315401
#
#                                                    url         scientificname  \
# 40   https://www.marinespecies.org/aphia.php?p=taxd...  Balaenoptera musculus
# 74   https://www.marinespecies.org/aphia.php?p=taxd...              Chrysaora
# 95   https://www.marinespecies.org/aphia.php?p=taxd...     Delphinus capensis
# 96   https://www.marinespecies.org/aphia.php?p=taxd...     Delphinus capensis
# 140  https://www.marinespecies.org/aphia.php?p=taxd...             Holothuria
#
#                        authority        status  \
# 40   Van Beneden & Gervais, 1880    unaccepted
# 74               Lamouroux, 1821    unaccepted
# 95                    Gray, 1828    unaccepted
# 96                    Rapp, 1837  nomen dubium
# 140               Linnaeus, 1758    unaccepted
#
#                                         unacceptreason  taxonRankID     rank  \
# 40                                             synonym          220  Species
# 74                                                None          180    Genus
# 95                                             synonym          220  Species
# 96                                      incertae sedis          220  Species
# 140  Treated as junior synonym of Physalia, Lamarcc...          180    Genus
#
#      valid_AphiaID  ...         genus  \
# 40          137091  ...  Balaenoptera
# 74         1372852  ...     Chrysaora
# 95          137094  ...     Delphinus
# 96            <NA>  ...     Delphinus
# 140         135382  ...    Holothuria
#
#                                               citation  \
# 40   Fordyce, E.; Perrin, W.F. (2023). World Cetace...
# 74   WoRMS (2023). Chrysaora Lamouroux, 1821&nbsp;&...
# 95   Fordyce, E.; Perrin, W.F. (2023). World Cetace...
# 96   Fordyce, E.; Perrin, W.F. (2023). World Cetace...
# 140  Schuchert, P. (2023). World Hydrozoa Database....
#
#                                            lsid isMarine isBrackish  \
# 40    urn:lsid:marinespecies.org:taxname:380449        1       <NA>
# 74   urn:lsid:marinespecies.org:taxname:1379174        1       <NA>
# 95    urn:lsid:marinespecies.org:taxname:137093        1          0
# 96    urn:lsid:marinespecies.org:taxname:383816        1       <NA>
# 140  urn:lsid:marinespecies.org:taxname:1315401        1          0
#
#     isFreshwater isTerrestrial isExtinct match_type                  modified
# 40          <NA>             0      <NA>      exact  2009-12-31T18:14:43.750Z
# 74          <NA>          <NA>         1      exact  2019-09-19T12:01:24.303Z
# 95             0             0      <NA>      exact  2016-05-05T05:59:43.010Z
# 96          <NA>             0      <NA>      exact  2009-03-05T14:31:36.587Z
# 140            0             0         0      exact  2021-05-28T05:40:56.327Z
#
# [5 rows x 28 columns]

# %%
df_expanded[df_expanded['species'] == 'Salmo trutta trutta']
# Out:
#                   species  AphiaID  \
# 1624  Salmo trutta trutta  1416249
# 1625  Salmo trutta trutta   223866
#
#                                                     url       scientificname  \
# 1624  https://www.marinespecies.org/aphia.php?p=taxd...  Salmo trutta trutta
# 1625  https://www.marinespecies.org/aphia.php?p=taxd...  Salmo trutta trutta
#
#            authority      status unacceptreason  taxonRankID        rank  \
# 1624   Walbaum, 1792  unaccepted           None          230  Subspecies
# 1625  Linnaeus, 1758  unaccepted           None          230  Subspecies
#
#       valid_AphiaID  ...  genus  \
# 1624         127188  ...  Salmo
# 1625         127187  ...  Salmo
#
#                                                citation  \
# 1624  Froese, R. and D. Pauly. Editors. (2023). Fish...
# 1625  Froese, R. and D. Pauly. Editors. (2023). Fish...
#
#                                             lsid isMarine isBrackish  \
# 1624  urn:lsid:marinespecies.org:taxname:1416249        1          1
# 1625   urn:lsid:marinespecies.org:taxname:223866        1          1
#
#      isFreshwater isTerrestrial isExtinct match_type                  modified
# 1624            1             0      <NA>      exact  2020-01-21T12:50:04.933Z
# 1625            1             0      <NA>      exact  2023-01-17T15:33:01.533Z
#
# [2 rows x 28 columns]

# %% [markdown]
# ### Join
